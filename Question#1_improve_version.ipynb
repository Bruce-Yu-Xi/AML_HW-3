# %% [markdown]
# # Question_1

# %% [markdown]
# ### import lib

# %%
from nltk.stem import WordNetLemmatizer
import nltk
from nltk.corpus import wordnet
from nltk.corpus import wordnet as wn
import numpy as np
import random
from sklearn.linear_model import LogisticRegression as LGR
from sklearn.cluster import KMeans

# %%
'this' in nltk.corpus.stopwords.words("english")
# Out:
# True

# %% [markdown]
# ### PreProcess data

# %%
# mapping picked up from https://github.com/pararthshah/qa-memnn/blob/master/nltk_utils.py

lemmatizer = WordNetLemmatizer()

def is_noun(tag):
    return tag in ['NN', 'NNS', 'NNP', 'NNPS']

def is_verb(tag):
    return tag in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']

def is_adverb(tag):
    return tag in ['RB', 'RBR', 'RBS']

def is_adjective(tag):
    return tag in ['JJ', 'JJR', 'JJS']

def penn_to_wn(tag):
    if is_adjective(tag):
        return wn.ADJ
    elif is_noun(tag):
        return wn.NOUN
    elif is_adverb(tag):
        return wn.ADV
    elif is_verb(tag):
        return wn.VERB
    return None


'''
takes in a list of tokens of length > 0
returns a list of the most likely part of speech for the token

'''
def get_pos(tokens):
    pos_list = nltk.pos_tag(tokens)
    #print(pos_list)
    pos_pegs = []
    for i, (token, pos) in enumerate(pos_list):        
        pos_peg = penn_to_wn(pos)
        if pos_peg is not None:
            pos_pegs.append(pos_peg)
        else:
            pos_pegs.append(None)
    return list(zip(tokens, pos_pegs))

def lemmatize(pos_tagged_tokens):
    lemmatized_tokens = []
    for i, (token, pos) in enumerate(pos_tagged_tokens):
        #print(token, pos)
        lemmatized_tokens.append(lemmatizer.lemmatize(token, pos=(pos if pos is not None else 'n')))
    return lemmatized_tokens

# %%
"""
train_data includes 2400 samples, where each sample is a list including the
elements which are the words in reviews.

train_label includes 2400 samples which belongs to {0,1}, which is the label 
of train_data.

test_data has the same form as the train_data, while it has 600 sample.

test_label is the same as train_label.
"""
def Split(filenames):

    train_data = []
    train_label = []
    test_data = []
    test_label = []
    root = "sentiment labelled sentences/"
    for filename in filenames:
        path = root + filename
        count = [1,1]
        punctuation = ["!","%","&","(",")","+",".",":",";","<","=",">","?","*",",","\t",""]
        #meanless = ["and", "or", "the"]
        for line in open(path):
            if line[-1] == "\n":
                line = line[:-1]
            a = int(line[-1])
            b=[]
            for word in line[:-1].split(' '):
                ##while word and word[-1] in punctuation:
                    ##word = word[:-1]
                ##b.append(wordnet_lemmatizer.lemmatize(word.lower()))
                i = 0
                while i < len(word):
                    if word[i] in punctuation:
                        word = word[:i]+word[i+1:]
                    else:
                        i+=1
                if not word:
                    continue
                pos_tagged_tokens = get_pos([word.lower()])
                c = lemmatize(pos_tagged_tokens)[0]
                if c in nltk.corpus.stopwords.words("english"):
                    continue
                b.append(c)
            if count[a] > 400:
                test_label.append(a)
                test_data.append(b)
            else:
                train_label.append(a)
                train_data.append(b)
            count[a]+=1
    return [train_data, train_label, test_data, test_label]

# %%
[train_data, train_label, test_data, test_label] = Split(["yelp_labelled.txt","amazon_cells_labelled.txt","imdb_labelled.txt"])

# %%
train_data
# Out:
# [['wow', 'love', 'place'],
#  ['crust', 'good'],
#  ['tasty', 'texture', 'nasty'],
#  ['stop',
#   'late',
#   'may',
#   'bank',
#   'holiday',
#   'rick',
#   'steve',
#   'recommendation',
#   'love'],
#  ['selection', 'menu', 'great', 'price'],
#  ['get', 'angry', 'want', 'damn', 'pho'],
#  ['honeslty', "didn't", 'taste', 'fresh'],
#  ['potato',
#   'like',
#   'rubber',
#   'could',
#   'tell',
#   'make',
#   'ahead',
#   'time',
#   'kept',
#   'warmer'],
#  ['fry', 'great'],
#  ['great', 'touch'],
#  ['service', 'prompt'],
#  ['would', 'go', 'back'],
#  ['cashier', 'care', 'ever', 'say', 'still', 'end', 'wayyy', 'overprice'],
#  ['try', 'cape', 'cod', 'ravoli', 'chickenwith', 'cranberrymmmm'],
#  ['disgust', 'pretty', 'sure', 'human', 'hair'],
#  ['shock', 'sign', 'indicate', 'cash'],
#  ['highly', 'recommend'],
#  ['waitress', 'little', 'slow', 'service'],
#  ['place', 'worth', 'time', 'let', 'alone', 'vega'],
#  ['like'],
#  ['burrittos', 'blah'],
#  ['food', 'amaze'],
#  ['service', 'also', 'cute'],
#  ['could', 'care', 'less', 'interior', 'beautiful'],
#  ['perform'],
#  ["that's", 'rightthe', 'red', 'velvet', 'cakeohhh', 'stuff', 'good'],
#  ['-', 'never', 'brought', 'salad', 'ask'],
#  ['hole', 'wall', 'great', 'mexican', 'street', 'taco', 'friendly', 'staff'],
#  ['take',
#   'hour',
#   'get',
#   'food',
#   '4',
#   'table',
#   'restaurant',
#   'food',
#   'luke',
#   'warm',
#   'sever',
#   'run',
#   'around',
#   'like',
#   'totally',
#   'overwhelmed'],
#  ['bad', 'salmon', 'sashimi'],
#  ['also', 'combo', 'like', 'burger', 'fry', 'beer', '23', 'decent', 'deal'],
#  ['like', 'final', 'blow'],
#  ['found', 'place', 'accident', 'could', 'happier'],
#  ['seem',
#   'like',
#   'good',
#   'quick',
#   'place',
#   'grab',
#   'bite',
#   'familiar',
#   'pub',
#   'food',
#   'favor',
#   'look',
#   'elsewhere'],
#  ['overall', 'like', 'place', 'lot'],
#  ['redeem', 'quality', 'restaurant', 'inexpensive'],
#  ['ample', 'portion', 'good', 'price'],
#  ['poor',
#   'service',
#   'waiter',
#   'make',
#   'feel',
#   'like',
#   'stupid',
#   'every',
#   'time',
#   'come',
#   'table'],
#  ['first', 'visit', 'hiro', 'delight'],
#  ['service', 'suck'],
#  ['shrimp', 'tender', 'moist'],
#  ['deal', 'good', 'enough', 'would', 'drag', 'establishment'],
#  ['hard',
#   'judge',
#   'whether',
#   'side',
#   'good',
#   'gross',
#   'melt',
#   'styrofoam',
#   "didn't",
#   'want',
#   'eat',
#   'fear',
#   'get',
#   'sick'],
#  ['positive', 'note', 'server', 'attentive', 'provide', 'great', 'service'],
#  ['frozen', 'puck', 'disgust', 'bad', 'people', 'behind', 'register'],
#  ['thing', 'like', 'prime', 'rib', 'dessert', 'section'],
#  ["it's", 'bad', 'food', 'damn', 'generic'],
#  ['burger', 'good', 'beef', 'cooked', 'right'],
#  ['want', 'sandwich', 'go', 'firehouse'],
#  ['side',
#   'greek',
#   'salad',
#   'greek',
#   'dress',
#   'tasty',
#   'pita',
#   'hummus',
#   'refresh'],
#  ['order',
#   'duck',
#   'rare',
#   'pink',
#   'tender',
#   'inside',
#   'nice',
#   'char',
#   'outside'],
#  ['come', 'run', 'u', 'realize', 'husband', 'left', 'sunglass', 'table'],
#  ['chow', 'mein', 'good'],
#  ['horrible',
#   'attitude',
#   'towards',
#   'customer',
#   'talk',
#   'one',
#   'customer',
#   "don't",
#   'enjoy',
#   'food'],
#  ['portion', 'huge'],
#  ['love',
#   'itfriendly',
#   'server',
#   'great',
#   'food',
#   'wonderful',
#   'imaginative',
#   'menu'],
#  ['heart',
#   'attack',
#   'grill',
#   'downtown',
#   'vega',
#   'absolutely',
#   'flat-lined',
#   'excuse',
#   'restaurant'],
#  ['much', 'seafood', 'like', '5', 'string', 'pasta', 'bottom'],
#  ['salad',
#   'right',
#   'amount',
#   'sauce',
#   'power',
#   'scallop',
#   'perfectly',
#   'cooked'],
#  ['ripped', 'banana', 'ripped', 'petrify', 'tasteless'],
#  ['least', 'think', 'refill', 'water', 'struggle', 'wave', '10', 'minute'],
#  ['place', 'receives', 'star', 'appetizer'],
#  ['cocktail', 'handmade', 'delicious'],
#  ["we'd", 'definitely', 'go', 'back'],
#  ['glad', 'found', 'place'],
#  ['great',
#   'food',
#   'service',
#   'huge',
#   'portion',
#   'give',
#   'military',
#   'discount'],
#  ['always', 'great', 'time', 'gringo'],
#  ['updatewent', 'back', 'second', 'time', 'still', 'amaze'],
#  ['get',
#   'food',
#   'apparently',
#   'never',
#   'heard',
#   'salt',
#   'batter',
#   'fish',
#   'chewy'],
#  ['great', 'way', 'finish', 'great'],
#  ['deal',
#   'include',
#   '5',
#   'tasting',
#   '2',
#   'drink',
#   'jeff',
#   'go',
#   'beyond',
#   'expect'],
#  ['-', 'really', 'really', 'good', 'rice', 'time'],
#  ['service', 'meh'],
#  ['take', '30', 'min', 'get', 'milkshake', 'nothing', 'chocolate', 'milk'],
#  ['guess',
#   'know',
#   'place',
#   'would',
#   'suck',
#   'inside',
#   'excalibur',
#   "didn't",
#   'use',
#   'common',
#   'sense'],
#  ['scallop', 'dish', 'quite', 'appal', 'value', 'well'],
#  ['2', 'time', '-', 'bad', 'customer', 'service'],
#  ['sweet', 'potato', 'fry', 'good', 'season', 'well'],
#  ['today', 'second', 'time', "i've", 'lunch', 'buffet', 'pretty', 'good'],
#  ['much',
#   'good',
#   'food',
#   'vega',
#   'feel',
#   'cheat',
#   'waste',
#   'eat',
#   'opportunity',
#   'go',
#   'rice',
#   'company'],
#  ['come',
#   'like',
#   'experience',
#   'underwhelming',
#   'relationship',
#   'party',
#   "can't",
#   'wait',
#   'person',
#   'ask',
#   'break'],
#  ['walk',
#   'place',
#   'smell',
#   'like',
#   'old',
#   'grease',
#   'trap',
#   '2',
#   'others',
#   'eat'],
#  ['turkey', 'roast', 'beef', 'bland'],
#  ['place'],
#  ['pan',
#   'cake',
#   'everyone',
#   'rave',
#   'taste',
#   'like',
#   'sugary',
#   'disaster',
#   'tailor',
#   'palate',
#   'six',
#   'year',
#   'old'],
#  ['love', 'pho', 'spring', 'roll', 'oh', 'yummy', 'try'],
#  ['poor',
#   'batter',
#   'meat',
#   'ratio',
#   'make',
#   'chicken',
#   'tender',
#   'unsatisfying'],
#  ['say', 'food', 'amaze'],
#  ['omelet', 'die'],
#  ['everything', 'fresh', 'delicious'],
#  ['summary', 'largely', 'disappoint', 'din', 'experience'],
#  ["it's",
#   'like',
#   'really',
#   'sexy',
#   'party',
#   'mouth',
#   "you're",
#   'outrageously',
#   'flirt',
#   'hottest',
#   'person',
#   'party'],
#  ['never', 'hard', 'rock', 'casino', 'never', 'ever', 'step', 'forward'],
#  ['best', 'breakfast', 'buffet'],
#  ['say', 'bye', 'bye', 'tip', 'lady'],
#  ["we'll", 'never', 'go'],
#  ['back'],
#  ['food', 'arrive', 'quickly'],
#  ['good'],
#  ['side', 'cafe', 'serf', 'really', 'good', 'food'],
#  ['server',
#   'fantastic',
#   'found',
#   'wife',
#   'love',
#   'roast',
#   'garlic',
#   'bone',
#   'marrow',
#   'add',
#   'extra',
#   'meal',
#   'another',
#   'marrow',
#   'go'],
#  ['good', 'thing', 'waiter', 'helpful', 'kept', 'bloddy', "mary's", 'come'],
#  ['best', 'buffet', 'town', 'price', 'cannot', 'beat'],
#  ['love',
#   'mussel',
#   'cooked',
#   'wine',
#   'reduction',
#   'duck',
#   'tender',
#   'potato',
#   'dish',
#   'delicious'],
#  ['one', 'well', 'buffet'],
#  ['go', 'tigerlilly', 'fantastic', 'afternoon'],
#  ['food',
#   'delicious',
#   'bartender',
#   'attentive',
#   'personable',
#   'get',
#   'great',
#   'deal'],
#  ['ambience', 'wonderful', 'music', 'play'],
#  ['go', 'back', 'next', 'trip'],
#  ['sooooo', 'good'],
#  ['real', 'sushi', 'lover', "let's", 'honest', '-', 'yama', 'good'],
#  ['least', '40min', 'pass', 'u', 'order', 'food', 'arrive', "wasn't", 'busy'],
#  ['really', 'fantastic', 'thai', 'restaurant', 'definitely', 'worth', 'visit'],
#  ['nice', 'spicy', 'tender'],
#  ['good', 'price'],
#  ['check'],
#  ['pretty', 'gross'],
#  ["i've", 'well', 'atmosphere'],
#  ['kind', 'hard', 'mess', 'steak'],
#  ['although',
#   'much',
#   'like',
#   'look',
#   'sound',
#   'place',
#   'actual',
#   'experience',
#   'bit',
#   'disappoint'],
#  ["don't",
#   'know',
#   'place',
#   'manage',
#   'serve',
#   'blandest',
#   'food',
#   'ever',
#   'eat',
#   'prepare',
#   'indian',
#   'cuisine'],
#  ['bad', 'service', 'boot', 'least', 'worry'],
#  ['service', 'fine', 'waitress', 'friendly'],
#  ['guy',
#   'steak',
#   'steak',
#   'love',
#   'son',
#   'steak',
#   'best',
#   'bad',
#   'place',
#   'say',
#   'best',
#   'steak',
#   "he's",
#   'ever',
#   'eat'],
#  ['thought',
#   "you'd",
#   'venture',
#   'far',
#   'away',
#   'get',
#   'good',
#   'sushi',
#   'place',
#   'really',
#   'hit',
#   'spot',
#   'night'],
#  ['host', 'staff', 'lack', 'well', 'word', 'bitch'],
#  ['bland',
#   'like',
#   'place',
#   'number',
#   'reason',
#   "don't",
#   'want',
#   'waste',
#   'time',
#   'bad',
#   'review',
#   "i'll",
#   'leave'],
#  ['phenomenal', 'food', 'service', 'ambiance'],
#  ["wouldn't", 'return'],
#  ['definitely',
#   'worth',
#   'venture',
#   'strip',
#   'pork',
#   'belly',
#   'return',
#   'next',
#   'time',
#   "i'm",
#   'vega'],
#  ['place', 'way', 'overprice', 'mediocre', 'food'],
#  ['penne', 'vodka', 'excellent'],
#  ['good',
#   'selection',
#   'food',
#   'include',
#   'massive',
#   'meatloaf',
#   'sandwich',
#   'crispy',
#   'chicken',
#   'wrap',
#   'delish',
#   'tuna',
#   'melt',
#   'tasty',
#   'burger'],
#  ['management', 'rude'],
#  ['delicious',
#   'nyc',
#   'bagel',
#   'good',
#   'selection',
#   'cream',
#   'cheese',
#   'real',
#   'lox',
#   'caper',
#   'even'],
#  ['great',
#   'subway',
#   'fact',
#   "it's",
#   'good',
#   'come',
#   'every',
#   'subway',
#   'meet',
#   'expectation'],
#  ['seriously', 'solid', 'breakfast'],
#  ['one', 'best', 'bar', 'food', 'vega'],
#  ['extremely',
#   'rude',
#   'really',
#   'many',
#   'restaurant',
#   'would',
#   'love',
#   'dine',
#   'weekend',
#   'vega'],
#  ['drink', 'never', 'empty', 'make', 'really', 'great', 'menu', 'suggestion'],
#  ["don't"],
#  ['waiter', "wasn't", 'helpful', 'friendly', 'rarely', 'checked', 'u'],
#  ['husband', 'ate', 'lunch', 'disappointed', 'food', 'service'],
#  ['red', 'curry', 'much', 'bamboo', 'shoot', "wasn't", 'tasty'],
#  ['nice', 'blanket', 'moz', 'top', 'feel', 'like', 'cover', 'subpar', 'food'],
#  ['bathroom', 'clean', 'place', 'well', 'decorate'],
#  ['menu',
#   'always',
#   'change',
#   'food',
#   'quality',
#   'go',
#   'service',
#   'extremely',
#   'slow'],
#  ['service',
#   'little',
#   'slow',
#   'consider',
#   'serve',
#   '3',
#   'people',
#   'server',
#   'food',
#   'come',
#   'slow',
#   'pace'],
#  ['give', '2', 'thumb'],
#  ['watch', 'waiter', 'pay', 'lot', 'attention', 'table', 'ignore', 'u'],
#  ['fiancé', 'come', 'middle', 'day', 'greet', 'seat', 'right', 'away'],
#  ['great', 'restaurant', 'mandalay', 'bay'],
#  ['wait', 'forty', 'five', 'minute', 'vain'],
#  ['crostini', 'come', 'salad', 'stale'],
#  ['highlight', 'great', 'quality', 'nigiri'],
#  ['staff', 'friendly', 'joint', 'always', 'clean'],
#  ['different',
#   'cut',
#   'piece',
#   'day',
#   'still',
#   'wonderful',
#   'tender',
#   'well',
#   'well',
#   'flavor'],
#  ['order',
#   'voodoo',
#   'pasta',
#   'first',
#   'time',
#   "i'd",
#   'really',
#   'excellent',
#   'pasta',
#   'since',
#   'go',
#   'gluten',
#   'free',
#   'several',
#   'year',
#   'ago'],
#  ['place', 'good'],
#  ['unfortunately',
#   'must',
#   'hit',
#   'bakery',
#   'leftover',
#   'day',
#   'everything',
#   'order',
#   'stale'],
#  ['come', 'back', 'today', 'since', 'relocate', 'still', 'impressed'],
#  ['seat', 'immediately'],
#  ['menu', 'diverse', 'reasonably', 'price'],
#  ['avoid', 'cost'],
#  ['restaurant', 'always', 'full', 'never', 'wait'],
#  ['delicious'],
#  ['place',
#   'hands-down',
#   'one',
#   'best',
#   'place',
#   'eat',
#   'phoenix',
#   'metro',
#   'area'],
#  ["don't", 'go', 'look', 'good', 'food'],
#  ["i've", 'never', 'treat', 'bad'],
#  ['bacon', 'hella', 'salty'],
#  ['also',
#   'order',
#   'spinach',
#   'avocado',
#   'salad',
#   'ingredient',
#   'sad',
#   'dress',
#   'literally',
#   'zero',
#   'taste'],
#  ['really',
#   'vega',
#   'fine',
#   'din',
#   'use',
#   'right',
#   'menu',
#   'hand',
#   'lady',
#   'price',
#   'list'],
#  ['waitress', 'friendly'],
#  ['lordy', 'khao', 'soi', 'dish', 'miss', 'curry', 'lover'],
#  ['everything',
#   'menu',
#   'terrific',
#   'also',
#   'thrill',
#   'make',
#   'amaze',
#   'accommodation',
#   'vegetarian',
#   'daughter'],
#  ['perhaps',
#   'caught',
#   'night',
#   'judging',
#   'review',
#   "i'm",
#   'inspire',
#   'go',
#   'back'],
#  ['service', 'leaf', 'lot', 'desire'],
#  ['atmosphere', 'modern', 'hip', 'maintain', 'touch', 'coziness'],
#  ['weekly', 'haunt', 'definitely', 'place', 'come', 'back', 'every'],
#  ['literally', 'sat', '20', 'minute', 'one', 'ask', 'take', 'order'],
#  ['burger',
#   'absolutely',
#   'flavor',
#   '-',
#   'meat',
#   'totally',
#   'bland',
#   'burger',
#   'overcook',
#   'charcoal',
#   'flavor'],
#  ['also',
#   'decide',
#   'send',
#   'back',
#   'waitress',
#   'look',
#   'like',
#   'verge',
#   'heart',
#   'attack'],
#  ['dress', 'treat', 'rudely'],
#  ['probably', 'dirt'],
#  ['love',
#   'place',
#   'hit',
#   'spot',
#   'want',
#   'something',
#   'healthy',
#   'lack',
#   'quantity',
#   'flavor'],
#  ['order', 'lemon', 'raspberry', 'ice', 'cocktail', 'also', 'incredible'],
#  ['food', 'suck', 'expect', 'suck', 'could', 'imagine'],
#  ['interest', 'decor'],
#  ['really', 'like', 'crepe', 'station'],
#  ['also',
#   'serve',
#   'hot',
#   'bread',
#   'butter',
#   'home',
#   'make',
#   'potato',
#   'chip',
#   'bacon',
#   'bit',
#   'topvery',
#   'original',
#   'good'],
#  ['watch', 'prepare', 'delicious', 'food'],
#  ['egg', 'roll', 'fantastic'],
#  ['order', 'arrive', 'one', 'gyro', 'miss'],
#  ['salad',
#   'wing',
#   'ice',
#   'cream',
#   'dessert',
#   'left',
#   'feel',
#   'quite',
#   'satisfied'],
#  ["i'm",
#   'really',
#   'sure',
#   "joey's",
#   'vote',
#   'best',
#   'hot',
#   'dog',
#   'valley',
#   'reader',
#   'phoenix',
#   'magazine'],
#  ['best', 'place', 'go', 'tasty', 'bowl', 'pho'],
#  ['live', 'music', 'friday', 'totally', 'blow'],
#  ["i've", 'never', 'insult', 'felt', 'disrespect'],
#  ['friendly', 'staff'],
#  ['worth', 'drive'],
#  ['heard',
#   'good',
#   'thing',
#   'place',
#   'exceed',
#   'every',
#   'hope',
#   'could',
#   'dream'],
#  ['food', 'great', 'serivce'],
#  ['warm', 'beer', "didn't", 'help'],
#  ['great', 'brunch', 'spot'],
#  ['service', 'friendly', 'invite'],
#  ['good', 'lunch', 'spot'],
#  ["i've",
#   'live',
#   'since',
#   '1979',
#   'first',
#   'last',
#   'time',
#   "i've",
#   'step',
#   'foot',
#   'place'],
#  ['bad', 'experience', 'ever'],
#  ['must', 'night', 'place'],
#  ['side',
#   'delish',
#   '-',
#   'mixed',
#   'mushroom',
#   'yukon',
#   'gold',
#   'puree',
#   'white',
#   'corn',
#   '-',
#   'beateous'],
#  ['bug',
#   'never',
#   'show',
#   'would',
#   'give',
#   '4',
#   'sure',
#   'side',
#   'wall',
#   'bug',
#   'climb',
#   'kitchen'],
#  ['10',
#   'minute',
#   "we're",
#   'wait',
#   'salad',
#   'realize',
#   "wasn't",
#   'come',
#   'time',
#   'soon'],
#  ['friend', 'love', 'salmon', 'tartar'],
#  ["won't", 'go', 'back'],
#  ['extremely', 'tasty'],
#  ['waitress', 'good', 'though'],
#  ['soggy', 'good'],
#  ['jamaican', 'mojitos', 'delicious'],
#  ['small', 'worth', 'price'],
#  ['-', 'food', 'rich', 'order', 'accordingly'],
#  ['shower',
#   'area',
#   'outside',
#   'rinse',
#   'take',
#   'full',
#   'shower',
#   'unless',
#   "don't",
#   'mind',
#   'nude',
#   'everyone',
#   'see'],
#  ['service', 'bit', 'lack'],
#  ['lobster',
#   'bisque',
#   'bussell',
#   'sprout',
#   'risotto',
#   'filet',
#   'need',
#   'salt',
#   'pepperand',
#   'course',
#   'none',
#   'table'],
#  ['hopefully', 'bodes', 'go', 'business', 'someone', 'cook', 'come'],
#  ['either', 'cold', 'enough', 'flavor', 'bad'],
#  ['love', 'bacon', 'wrap', 'date'],
#  ['unbelievable', 'bargain'],
#  ['folk', 'otto', 'always', 'make', 'u', 'feel', 'welcome', 'special'],
#  ['"mains"', 'also', 'uninspired'],
#  ['place', 'first', 'pho', 'amaze'],
#  ['wonderful', 'experience', 'make', 'place', 'must-stop', 'whenever', 'town'],
#  ['food',
#   "isn't",
#   'bad',
#   'enough',
#   'enjoy',
#   'deal',
#   "world's",
#   'worst/annoying',
#   'drunk',
#   'people'],
#  ['fun', 'chef'],
#  ['order',
#   'double',
#   'cheeseburger',
#   'get',
#   'single',
#   'patty',
#   'fall',
#   'apart',
#   'picture',
#   'uploaded',
#   'yeah',
#   'still',
#   'suck'],
#  ['great',
#   'place',
#   'couple',
#   'drink',
#   'watch',
#   'sport',
#   'event',
#   'wall',
#   'cover',
#   "tv's"],
#  ['possible', 'give', 'zero', 'star', "they'd"],
#  ['description',
#   'say',
#   '"yum',
#   'yum',
#   'sauce"',
#   'another',
#   'say',
#   '"eel',
#   'sauce"',
#   'yet',
#   'another',
#   'say',
#   '"spicy',
#   'mayo"well',
#   'none',
#   'roll',
#   'sauce'],
#  ["i'd",
#   'say',
#   'would',
#   'hardest',
#   'decision',
#   'honestly',
#   "m's",
#   'dish',
#   'taste',
#   'suppose',
#   'taste',
#   'amaze'],
#  ['roll', 'eye', 'may', 'stayed', 'sure', 'go', 'back', 'try'],
#  ['everyone', 'attentive', 'provide', 'excellent', 'customer', 'service'],
#  ['horrible', '-', "don't", 'waste', 'time', 'money'],
#  ['dish', 'quite', 'flavourful'],
#  ['time', 'side', 'restaurant', 'almost', 'empty', 'excuse'],
#  ["wasn't", 'busy', 'either', 'also', 'building', 'freeze', 'cold'],
#  ['like',
#   'reviewer',
#   'say',
#   '"you',
#   "couldn't",
#   'pay',
#   'eat',
#   'place',
#   'again"'],
#  ['-drinks', 'take', 'close', '30', 'minute', 'come', 'one', 'point'],
#  ['seriously', 'flavorful', 'delight', 'folk'],
#  ['much', 'well', 'ayce', 'sushi', 'place', 'go', 'vega'],
#  ['light', 'dark', 'enough', 'set', 'mood'],
#  ['base',
#   'sub-par',
#   'service',
#   'receive',
#   'effort',
#   'show',
#   'gratitude',
#   'business',
#   "won't",
#   'go',
#   'back'],
#  ["owner's", 'really', 'great', 'people'],
#  ['nothing', 'privileged', 'working/eating'],
#  ['greek', 'dress', 'creamy', 'flavorful'],
#  ['overall',
#   "don't",
#   'think',
#   'would',
#   'take',
#   'parent',
#   'place',
#   'make',
#   'similar',
#   'complaint',
#   'silently',
#   'felt'],
#  ['pizza', 'good', 'peanut', 'sauce', 'tasty'],
#  ['7', 'table', 'service', 'pretty', 'fast'],
#  ['fantastic', 'service'],
#  ['well', "would've", 'give', 'godfather', 'zero', 'star', 'possible'],
#  ['know', 'make'],
#  ['tough', 'short', 'flavor'],
#  ['hope', 'place', 'stick', 'around'],
#  ['bar', 'vega', 'ever', 'recall', 'charge', 'tap', 'water'],
#  ['restaurant', 'atmosphere', 'exquisite'],
#  ['good', 'service', 'clean', 'inexpensive', 'boot'],
#  ['seafood', 'fresh', 'generous', 'portion'],
#  ['plus', "it's", '8', 'buck'],
#  ['service', 'par', 'either'],
#  ['thus', 'far', 'visit', 'twice', 'food', 'absolutely', 'delicious', 'time'],
#  ['good', 'year', 'ago'],
#  ['self', 'proclaim', 'coffee', 'cafe', 'wildly', 'disappointed'],
#  ['veggitarian', 'platter', 'world'],
#  ['cant', 'go', 'wrong', 'food'],
#  ["can't", 'beat'],
#  ['stop', 'place', 'madison', 'ironman', 'friendly', 'kind', 'staff'],
#  ['chef', 'friendly', 'good', 'job'],
#  ["i've", 'well', 'dedicate', 'boba', 'tea', 'spot', 'even', 'jenni', 'pho'],
#  ['like', 'patio', 'service', 'outstanding'],
#  ['goat', 'taco', "didn't", 'skimp', 'meat', 'wow', 'flavor'],
#  ['think'],
#  ['mac', 'salad', 'pretty', 'bland', 'get'],
#  ['go', 'bachi', 'burger', "friend's", 'recommendation', 'disappointed'],
#  ['service', 'stink'],
#  ['wait', 'wait'],
#  ['place', 'quality', 'sushi', 'quality', 'restaurant'],
#  ['would', 'definitely', 'recommend', 'wing', 'well', 'pizza'],
#  ['great', 'pizza', 'salad'],
#  ['thing', 'go', 'wrong', '-', 'burn', 'saganaki'],
#  ['wait', 'hour', 'breakfast', 'could', '100', 'time', 'well', 'home'],
#  ['place', 'amaze'],
#  ['hate', 'disagree', 'fellow', 'yelpers', 'husband', 'disappointed', 'place'],
#  ['wait',
#   '2',
#   'hour',
#   'never',
#   'get',
#   'either',
#   'pizza',
#   'many',
#   'around',
#   'u',
#   'come',
#   'later'],
#  ["don't", 'know', 'slow'],
#  ['staff', 'great', 'food', 'delish', 'incredible', 'beer', 'selection'],
#  ['live',
#   'neighborhood',
#   'disappointed',
#   "won't",
#   'back',
#   'convenient',
#   'location'],
#  ["didn't", 'know', 'pull', 'pork', 'could', 'soooo', 'delicious'],
#  ['get', 'incredibly', 'fresh', 'fish', 'prepared', 'care'],
#  ['go',
#   'give',
#   '1',
#   'star',
#   'rating',
#   'please',
#   'know',
#   'third',
#   'time',
#   'eat',
#   'bachi',
#   'burger',
#   'write',
#   'review'],
#  ['love', 'fact', 'everything', 'menu', 'worth'],
#  ['never', 'din', 'place'],
#  ['food', 'excellent', 'service', 'good'],
#  ['good', 'beer', 'drink', 'selection', 'good', 'food', 'selection'],
#  ['please', 'stay', 'away', 'shrimp', 'stir', 'fry', 'noodle'],
#  ['potato',
#   'chip',
#   'order',
#   'sad',
#   'could',
#   'probably',
#   'count',
#   'many',
#   'chip',
#   'box',
#   'probably',
#   'around',
#   '12'],
#  ['food', 'really', 'boring'],
#  ['good', 'service-check'],
#  ['greedy', 'corporation', 'never', 'see', 'another', 'dime'],
#  ['never', 'ever', 'go', 'back'],
#  ['much',
#   "i'd",
#   'like',
#   'go',
#   'back',
#   "can't",
#   'get',
#   'pass',
#   'atrocious',
#   'service',
#   'never',
#   'return'],
#  ['summer', 'dine', 'charm', 'outdoor', 'patio', '-', 'delightful'],
#  ['expect', 'good'],
#  ['fantastic', 'food'],
#  ['order', 'toast', 'english', 'muffin', 'come', 'untoasted'],
#  ['food', 'good'],
#  ['never', 'go', 'back'],
#  ['great', 'food', 'price', 'high', 'quality', 'house', 'make'],
#  ['bus', 'boy', 'hand', 'rude'],
#  ['point',
#   'friend',
#   'basically',
#   'figure',
#   'place',
#   'joke',
#   "didn't",
#   'mind',
#   'make',
#   'publicly',
#   'loudly',
#   'know'],
#  ['back',
#   'good',
#   'bbq',
#   'lighter',
#   'fare',
#   'reasonable',
#   'pricing',
#   'tell',
#   'public',
#   'back',
#   'old',
#   'way'],
#  ['consider',
#   'two',
#   'u',
#   'left',
#   'full',
#   'happy',
#   '$20',
#   "can't",
#   'go',
#   'wrong'],
#  ['bread', 'make', 'in-house'],
#  ['downside', 'service'],
#  ['also', 'fry', 'without', 'doubt', 'bad', 'fry', "i've", 'ever'],
#  ['service', 'exceptional', 'food', 'good', 'review'],
#  ['couple', 'month', 'later', 'return', 'amaze', 'meal'],
#  ['favorite', 'place', 'town', 'shawarrrrrrma'],
#  ['black', 'eyed', 'pea', 'sweet', 'potato', 'unreal'],
#  ["won't", 'disappointed'],
#  ['could',
#   'serve',
#   'vinaigrette',
#   'may',
#   'make',
#   'well',
#   'overall',
#   'dish',
#   'still',
#   'good'],
#  ['go',
#   'far',
#   'many',
#   'place',
#   "i've",
#   'never',
#   'see',
#   'restaurant',
#   'serf',
#   '1',
#   'egg',
#   'breakfast',
#   'especially',
#   '$400'],
#  ['mom', 'get', 'home', 'immediately', 'get', 'sick', 'bite', 'salad'],
#  ['server',
#   'pleasant',
#   'deal',
#   "don't",
#   'always',
#   'honor',
#   'pizza',
#   'hut',
#   'coupon'],
#  ['truly', 'unbelievably', 'good', 'glad', 'go', 'back'],
#  ['fantastic', 'service', 'pleased', 'atmosphere'],
#  ['everything', 'gross'],
#  ['love', 'place'],
#  ['great', 'service', 'food'],
#  ['first',
#   '-',
#   'bathroom',
#   'location',
#   'dirty-',
#   'seat',
#   'cover',
#   'replenish',
#   'plain',
#   'yucky'],
#  ['burger',
#   'get',
#   '"gold',
#   'standard"',
#   '$17',
#   'burger',
#   'kind',
#   'disappointed'],
#  ['omg', 'food', 'delicioso'],
#  ['nothing', 'authentic', 'place'],
#  ['spaghetti', 'nothing', 'special', 'whatsoever'],
#  ['dish', 'salmon', 'best', 'great'],
#  ['vegetable', 'fresh', 'sauce', 'feel', 'like', 'authentic', 'thai'],
#  ["it's", 'worth', 'drive', 'tucson'],
#  ['selection', 'probably', 'bad', "i've", 'see', 'vegasthere', 'none'],
#  ['pretty', 'good', 'beer', 'selection'],
#  ['place', 'like', 'chipotle', 'well'],
#  ['classy/warm',
#   'atmosphere',
#   'fun',
#   'fresh',
#   'appetizer',
#   'succulent',
#   'steak',
#   'baseball',
#   'steak'],
#  ['5', 'star', 'brick', 'oven', 'bread', 'app'],
#  ['eat', 'multiple', 'time', 'time', 'food', 'delicious'],
#  ['sat', 'another', 'ten', 'minute', 'finally', 'give', 'left'],
#  ['terrible'],
#  ['everyone', 'treat', 'equally', 'special'],
#  ["shouldn't", 'take', '30', 'min', 'pancake', 'egg'],
#  ['delicious'],
#  ['good',
#   'side',
#   'staff',
#   'genuinely',
#   'pleasant',
#   'enthusiastic',
#   '-',
#   'real',
#   'treat'],
#  ['sadly',
#   'gordon',
#   "ramsey's",
#   'steak',
#   'place',
#   'shall',
#   'sharply',
#   'avoid',
#   'next',
#   'trip',
#   'vega'],
#  ['always', 'even', 'wonderful', 'food', 'delicious'],
#  ['best', 'fish', "i've", 'ever', 'life'],
#  ['bathroom', 'next', 'door', 'nice'],
#  ['buffet', 'small', 'food', 'offer', 'bland'],
#  ['outstanding', 'little', 'restaurant', 'best', 'food', 'ever', 'taste'],
#  ['pretty', 'cool', 'would', 'say'],
#  ['definitely',
#   'turn',
#   'doubt',
#   "i'll",
#   'back',
#   'unless',
#   'someone',
#   'else',
#   'buying'],
#  ['server', 'great', 'job', 'handle', 'large', 'rowdy', 'table'],
#  ['find', 'waste', 'food', 'despicable', "wasn't", 'food'],
#  ['wife', 'lobster', 'bisque', 'soup', 'lukewarm'],
#  ['would', 'come', 'back', 'sushi', 'crave', 'vega'],
#  ['staff', 'great', 'ambiance', 'great'],
#  ['deserves', '5', 'star'],
#  ['left', 'stomach', 'ache', 'felt', 'sick', 'rest', 'day'],
#  ['drop', 'ball'],
#  ['din', 'space', 'tiny', 'elegantly', 'decorate', 'comfortable'],
#  ['customize',
#   'order',
#   'way',
#   "you'd",
#   'like',
#   'usual',
#   'eggplant',
#   'green',
#   'bean',
#   'stir',
#   'fry',
#   'love'],
#  ['bean', 'rice', 'mediocre', 'best'],
#  ['best', 'taco', 'town', 'far'],
#  ['take', 'back', 'money', 'get', 'outta'],
#  ['interest', 'part', 'town', 'place', 'amaze'],
#  ['rude', 'inconsiderate', 'management'],
#  ['staff',
#   'friendly',
#   'wait',
#   'time',
#   'serve',
#   'horrible',
#   'one',
#   'even',
#   'say',
#   'hi',
#   'first',
#   '10',
#   'minute'],
#  ["won't", 'back'],
#  ['great', 'dinner'],
#  ['service', 'outshine', 'definitely', 'recommend', 'halibut'],
#  ['food', 'terrible'],
#  ['never', 'ever', 'go', 'back', 'told', 'many', 'people', 'happen'],
#  ["don't", 'recommend', 'unless', 'car', 'break', 'front', 'starve'],
#  ['come', 'back', 'every', 'time', "i'm", 'vega'],
#  ['place', 'deserves', 'one', 'star', '90', 'food'],
#  ['disgrace'],
#  ['def', 'come', 'back', 'bowl', 'next', 'time'],
#  ['want', 'healthy', 'authentic', 'ethic', 'food', 'try', 'place'],
#  ['continue',
#   'come',
#   'lady',
#   'night',
#   'andddd',
#   'date',
#   'night',
#   'highly',
#   'recommend',
#   'place',
#   'anyone',
#   'area'],
#  ['several', 'time', 'past', 'experience', 'always', 'great'],
#  ['walk', 'away', 'stuffed', 'happy', 'first', 'vega', 'buffet', 'experience'],
#  ['service',
#   'excellent',
#   'price',
#   'pretty',
#   'reasonable',
#   'consider',
#   'vega',
#   'locate',
#   'inside',
#   'crystal',
#   'shopping',
#   'mall',
#   'aria'],
#  ['summarize',
#   'food',
#   'incredible',
#   'nay',
#   'transcendant',
#   'nothing',
#   'brings',
#   'joy',
#   'quite',
#   'like',
#   'memory',
#   'pneumatic',
#   'condiment',
#   'dispenser'],
#  ["i'm", 'probably', 'one', 'people', 'ever', 'go', 'ians', 'like'],
#  ['kid',
#   'pizza',
#   'always',
#   'hit',
#   'lot',
#   'great',
#   'side',
#   'dish',
#   'option',
#   'kiddos'],
#  ['service', 'perfect', 'family', 'atmosphere', 'nice', 'see'],
#  ['cooked', 'perfection', 'service', 'impeccable'],
#  ['one', 'simply', 'disappointment'],
#  ['overall', 'disappointed', 'quality', 'food', 'bouchon'],
#  ["don't", 'accountant', 'know', "i'm", 'get', 'screw'],
#  ['great',
#   'place',
#   'eat',
#   'reminds',
#   'little',
#   'mom',
#   'pop',
#   'shop',
#   'san',
#   'francisco',
#   'bay',
#   'area'],
#  ['today',
#   'first',
#   'taste',
#   'buldogis',
#   'gourmet',
#   'hot',
#   'dog',
#   'tell',
#   'ever',
#   'thought',
#   'possible'],
#  ['left', 'frustrate'],
#  ["i'll", 'definitely', 'soon'],
#  ['food', 'really', 'good', 'get', 'full', 'petty', 'fast'],
#  ['service', 'fantastic'],
#  ['total', 'waste', 'time'],
#  ["don't", 'know', 'kind', 'best', 'iced', 'tea'],
#  ['come', 'hungry', 'leave', 'happy', 'stuffed'],
#  ['service', 'give', 'star'],
#  ['assure', "won't", 'disappointed'],
#  ['take', 'little', 'bad', 'service', 'food', 'suck'],
#  ['give', 'try', 'eat', 'crust', 'teeth', 'still', 'sore'],
#  ['completely', 'gross'],
#  ['really', 'enjoy', 'eat'],
#  ['first', 'time', 'go', 'think', 'quickly', 'become', 'regular'],
#  ['server',
#   'nice',
#   'even',
#   'though',
#   'look',
#   'little',
#   'overwhelmed',
#   'need',
#   'stayed',
#   'professional',
#   'friendly',
#   'end'],
#  ['dinner',
#   'companion',
#   'told',
#   'meeverything',
#   'fresh',
#   'nice',
#   'texture',
#   'taste'],
#  ['ground',
#   'right',
#   'next',
#   'table',
#   'large',
#   'smear',
#   'been-stepped-in-and-tracked-everywhere',
#   'pile',
#   'green',
#   'bird',
#   'poop'],
#  ['furthermore', "can't", 'even', 'find', 'hour', 'operation', 'website'],
#  ["we've", 'try', 'like', 'place', '10', 'time', 'think', "we're"],
#  ['mistake'],
#  ['complaint'],
#  ['seriously', 'good', 'pizza', "i'm", 'expert/connisseur', 'topic'],
#  ['waiter', 'jerk'],
#  ['strike', '2', 'want', 'rush'],
#  ['nice', 'restaurant', 'owner', "i've", 'ever', 'come', 'across'],
#  ['never', 'come'],
#  ['love', 'biscuit'],
#  ['service', 'quick', 'friendly'],
#  ['order',
#   'appetizer',
#   'take',
#   '40',
#   'minute',
#   'pizza',
#   'another',
#   '10',
#   'minute'],
#  ['absolutley', 'fantastic'],
#  ['huge', 'awkward', '15lb', 'piece', 'cow', '3/4ths', 'gristle', 'fat'],
#  ['definitely', 'come', 'back'],
#  ['like', 'steiner', "it's", 'dark', 'feel', 'like', 'bar'],
#  ['wow', 'spicy', 'delicious'],
#  ["you're", 'familiar', 'check'],
#  ["i'll", 'take', 'business', 'dinner', 'dollar', 'elsewhere'],
#  ["i'd", 'love', 'go', 'back'],
#  ['anyway', 'f', 'restaurant', 'wonderful', 'breakfast/lunch'],
#  ['nothing', 'special'],
#  ['day', 'week', 'different', 'deal', "it's", 'delicious'],
#  ['mention', 'combination', 'pear', 'almond', 'bacon', 'big', 'winner'],
#  ['back'],
#  ['sauce', 'tasteless'],
#  ['food',
#   'delicious',
#   'spicy',
#   'enough',
#   'sure',
#   'ask',
#   'spicier',
#   'prefer',
#   'way'],
#  ['ribeye', 'steak', 'cooked', 'perfectly', 'great', 'mesquite', 'flavor'],
#  ["don't", 'think', "we'll", 'go', 'back', 'anytime', 'soon'],
#  ['food', 'gooodd'],
#  ['far',
#   'sushi',
#   'connoisseur',
#   'definitely',
#   'tell',
#   'difference',
#   'good',
#   'food',
#   'bad',
#   'food',
#   'certainly',
#   'bad',
#   'food'],
#  ['insult'],
#  ['last', '3', 'time', 'lunch', 'bad'],
#  ['chicken', 'wing', 'contain', 'driest', 'chicken', 'meat', 'ever', 'eat'],
#  ['food',
#   'good',
#   'enjoy',
#   'every',
#   'mouthful',
#   'enjoyable',
#   'relaxed',
#   'venue',
#   'couple',
#   'small',
#   'family',
#   'group',
#   'etc'],
#  ['nargile', '-', 'think', 'great'],
#  ['best', 'tater', 'tot', 'southwest'],
#  ['love', 'place'],
#  ['definitely', 'worth', '$3', 'paid'],
#  ['vanilla',
#   'ice',
#   'cream',
#   'creamy',
#   'smooth',
#   'profiterole',
#   'chou',
#   'pastry',
#   'fresh',
#   'enough'],
#  ['im', 'az', 'time', 'new', 'spot'],
#  ['manager', 'bad'],
#  ['inside', 'really', 'quite', 'nice', 'clean'],
#  ['food', 'outstanding', 'price', 'reasonable'],
#  ["don't",
#   'think',
#   "i'll",
#   'run',
#   'back',
#   "carly's",
#   'anytime',
#   'soon',
#   'food'],
#  ['due',
#   'fact',
#   'take',
#   '20',
#   'minute',
#   'acknowledge',
#   'another',
#   '35',
#   'minute',
#   'get',
#   'foodand',
#   'kept',
#   'forget',
#   'thing'],
#  ['love', 'margarita'],
#  ['first', 'vega', 'buffet', 'disappoint'],
#  ['good', 'though'],
#  ['one', 'note', 'ventilation', 'could', 'use', 'upgrade'],
#  ['great', 'pork', 'sandwich'],
#  ["don't", 'waste', 'time'],
#  ['total',
#   'letdown',
#   'would',
#   'much',
#   'rather',
#   'go',
#   'camelback',
#   'flower',
#   'shop',
#   'cartel',
#   'coffee'],
#  ['third', 'cheese', "friend's", 'burger', 'cold'],
#  ['enjoy', 'pizza', 'brunch'],
#  ['steak', 'well', 'trim', 'also', 'perfectly', 'cooked'],
#  ['group', '70', 'claimed', 'would', '40', 'handle', 'u', 'beautifully'],
#  ['love'],
#  ['ask', 'bill', 'leave', 'without', 'eat', "didn't", 'bring', 'either'],
#  ['place',
#   'jewel',
#   'la',
#   'vega',
#   'exactly',
#   "i've",
#   'hop',
#   'find',
#   'nearly',
#   'ten',
#   'year',
#   'living'],
#  ['seafood',
#   'limited',
#   'boil',
#   'shrimp',
#   'crab',
#   'leg',
#   'crab',
#   'leg',
#   'definitely',
#   'taste',
#   'fresh'],
#  ['selection', 'food', 'best'],
#  ['delicious', 'absolutely', 'back'],
#  ["isn't", 'small', 'family', 'restaurant', 'fine', 'din', 'establishment'],
#  ['toro',
#   'tartare',
#   'cavier',
#   'extraordinary',
#   'like',
#   'thinly',
#   'slice',
#   'wagyu',
#   'white',
#   'truffle'],
#  ['dont', 'think', 'back', 'long', 'time'],
#  ['attach', 'gas', 'station', 'rarely', 'good', 'sign'],
#  ['awesome'],
#  ['back', 'many', 'time', 'soon'],
#  ['menu', 'much', 'good', 'stuff', 'could', 'decide'],
#  ['bad',
#   'humiliate',
#   'worker',
#   'right',
#   'front',
#   'mebunch',
#   'horrible',
#   'name',
#   'calling'],
#  ['conclusion', 'fill', 'meal'],
#  ['daily', 'special', 'always', 'hit', 'group'],
#  ['tragedy', 'struck'],
#  ['pancake', 'also', 'really', 'good', 'pretty', 'large'],
#  ['first', 'crawfish', 'experience', 'delicious'],
#  ['monster', 'chicken', 'fry', 'steak', 'egg', 'time', 'favorite'],
#  ['waitress', 'sweet', 'funny'],
#  ['also',
#   'taste',
#   "mom's",
#   'multi-grain',
#   'pumpkin',
#   'pancake',
#   'pecan',
#   'butter',
#   'amaze',
#   'fluffy',
#   'delicious'],
#  ["i'd", 'rather', 'eat', 'airline', 'food', 'seriously'],
#  ['cant', 'say', 'enough', 'good', 'thing', 'place'],
#  ['ambiance', 'incredible'],
#  ['waitress', 'manager', 'friendly'],
#  ['would', 'recommend', 'place'],
#  ['overall', "wasn't", 'impressed', 'noca'],
#  ['gyro', 'basically', 'lettuce'],
#  ['terrible', 'service'],
#  ['thoroughly', 'disappointed'],
#  ["don't",
#   'much',
#   'pasta',
#   'love',
#   'homemade',
#   '/hand',
#   'make',
#   'pasta',
#   'thin',
#   'pizza'],
#  ['give', 'try', 'happy'],
#  ['far', 'best', 'cheesecurds', 'ever'],
#  ['reasonably', 'price', 'also'],
#  ['everything', 'perfect', 'night'],
#  ['food', 'good', 'typical', 'bar', 'food'],
#  ['drive', 'get'],
#  ['first',
#   'glance',
#   'lovely',
#   'bakery',
#   'cafe',
#   '-',
#   'nice',
#   'ambiance',
#   'clean',
#   'friendly',
#   'staff'],
#  ['anyway', 'think', 'go', 'back'],
#  ['point', 'finger', 'item', 'menu', 'order', "won't", 'disappointed'],
#  ['oh', 'thing', 'beauty', 'restaurant'],
#  ["haven't", 'go', 'go'],
#  ['greasy', 'unhealthy', 'meal'],
#  ['first', 'time', 'might', 'last'],
#  ['burger', 'amaze'],
#  ['similarly',
#   'delivery',
#   'man',
#   'say',
#   'word',
#   'apology',
#   'food',
#   '45',
#   'minute',
#   'late'],
#  ['way', 'expensive'],
#  ['sure',
#   'order',
#   'dessert',
#   'even',
#   'need',
#   'pack',
#   'to-go',
#   '-',
#   'tiramisu',
#   'cannoli',
#   'die'],
#  ['first', 'time', "can't", 'wait', 'next'],
#  ['bartender', 'also', 'nice'],
#  ['everything', 'good', 'tasty'],
#  ['place', 'two', 'thumb', 'upway'],
#  ['best', 'place', 'vega', 'breakfast', 'check', 'sat', 'sun'],
#  ['love',
#   'authentic',
#   'mexican',
#   'food',
#   'want',
#   'whole',
#   'bunch',
#   'interest',
#   'yet',
#   'delicious',
#   'meat',
#   'choose',
#   'need',
#   'try',
#   'place'],
#  ['terrible', 'management'],
#  ['excellent', 'new', 'restaurant', 'experienced', 'frenchman'],
#  ['zero', 'star', 'would', 'give', 'zero', 'star'],
#  ['great', 'steak', 'great', 'side', 'great', 'wine', 'amaze', 'dessert'],
#  ['bad', 'martini', 'ever'],
#  ['steak', 'shrimp', 'opinion', 'best', 'entree', 'gc'],
#  ['opportunity', 'today', 'sample', 'amaze', 'pizza'],
#  ['wait',
#   'thirty',
#   'minute',
#   'seat',
#   'although',
#   '8',
#   'vacant',
#   'table',
#   'folk',
#   'wait'],
#  ['yellowtail', 'carpaccio', 'melt', 'mouth', 'fresh'],
#  ["won't", 'try', 'go', 'back', 'even', "it's", 'empty'],
#  ["i'm", 'go', 'eat', 'potato', 'found', 'stranger', 'hair'],
#  ['spicy', 'enough', 'perfect', 'actually'],
#  ['last', 'night', 'second', 'time', 'din', 'happy', 'decide', 'go', 'back'],
#  ['even', '"hello', 'right', 'you"'],
#  ['dessert', 'bit', 'strange'],
#  ['boyfriend',
#   'come',
#   'first',
#   'time',
#   'recent',
#   'trip',
#   'vega',
#   'could',
#   'pleased',
#   'quality',
#   'food',
#   'service'],
#  ['really', 'recommend', 'place', 'go', 'wrong', 'donut', 'place'],
#  ['nice', 'ambiance'],
#  ['would', 'recommend', 'save', 'room'],
#  ['guess', 'maybe', 'go', 'night', 'disgraceful'],
#  ['however', 'recent', 'experience', 'particular', 'location', 'good'],
#  ['know', 'like', 'restaurant', 'something'],
#  ['avoid', 'establishment'],
#  ['think', 'restaurant', 'suffers', 'try', 'hard', 'enough'],
#  ['tapa', 'dish', 'delicious'],
#  ['heart', 'place'],
#  ['salad', 'bland', 'vinegrette', 'baby', 'green', 'heart', 'palm'],
#  ['two', 'felt', 'disgust'],
#  ['good', 'time'],
#  ['believe', 'place', 'great', 'stop', 'huge', 'belly', 'hanker', 'sushi'],
#  ['generous', 'portion', 'great', 'taste'],
#  ['never',
#   'go',
#   'back',
#   'place',
#   'never',
#   'ever',
#   'recommend',
#   'place',
#   'anyone'],
#  ['server',
#   'go',
#   'back',
#   'forth',
#   'several',
#   'time',
#   'even',
#   'much',
#   '"are',
#   'helped"'],
#  ['food', 'delicious'],
#  ['hour', 'seriously'],
#  ['consider', 'theft'],
#  ['eew', 'location', 'need', 'complete', 'overhaul'],
#  ['recently',
#   'witness',
#   'poor',
#   'quality',
#   'management',
#   'towards',
#   'guest',
#   'well'],
#  ['wait', 'wait', 'wait'],
#  ['also', 'come', 'back', 'check', 'u', 'regularly', 'excellent', 'service'],
#  ['server', 'super', 'nice', 'checked', 'u', 'many', 'time'],
#  ['pizza', 'taste', 'old', 'super', 'chewy', 'good', 'way'],
#  ['swung', 'give', 'try', 'deeply', 'disappointed'],
#  ['service', 'good', 'company', 'well'],
#  ['staff', 'also', 'friendly', 'efficient'],
#  ['service', "i'm", 'fan', "it's", 'quick', "you're", 'serve', 'nice', 'folk'],
#  ['boy', 'sucker', 'dry'],
#  ['rat'],
#  ['look', 'authentic', 'thai', 'food', 'go', 'else'],
#  ['steak', '100', 'recommend'],
#  ['pull', 'car', 'wait', 'another', '15', 'minute', 'acknowledge'],
#  ['great', 'food', 'great', 'service', 'clean', 'friendly', 'set'],
#  ['assure', "i'll", 'back'],
#  ['hate', 'thing', 'much', 'cheap', 'quality', 'black', 'olive'],
#  ['breakfast',
#   'perpared',
#   'great',
#   'beautiful',
#   'presentation',
#   '3',
#   'giant',
#   'slice',
#   'toast',
#   'lightly',
#   'dust',
#   'powder',
#   'sugar'],
#  ['kid', 'play', 'area', 'nasty'],
#  ['great', 'place', 'fo', 'take', 'eat'],
#  ['waitress', 'friendly', 'happy', 'accomodate', 'vegan/veggie', 'option'],
#  ['omg', 'felt', 'like', 'never', 'eat', 'thai', 'food', 'dish'],
#  ['extremely', '"crumby"', 'pretty', 'tasteless'],
#  ['pale', 'color', 'instead', 'nice', 'char', 'flavor'],
#  ['crouton', 'also', 'taste', 'homemade', 'extra', 'plus'],
#  ['get', 'home', 'see', 'driest', 'damn', 'wing', 'ever'],
#  ["it'll", 'regular', 'stop', 'trip', 'phoenix'],
#  ['really',
#   'enjoy',
#   'crema',
#   'café',
#   'expand',
#   'even',
#   'told',
#   'friend',
#   'best',
#   'breakfast'],
#  ['good', 'money'],
#  ['miss', 'wish', 'one', 'philadelphia'],
#  ['get',
#   'sit',
#   'fairly',
#   'fast',
#   'end',
#   'wait',
#   '40',
#   'minute',
#   'place',
#   'order',
#   'another',
#   '30',
#   'minute',
#   'food',
#   'arrive'],
#  ['also', 'best', 'cheese', 'crisp', 'town'],
#  ['good', 'value', 'great', 'food', 'great', 'service'],
#  ["couldn't", 'ask', 'satisfy', 'meal'],
#  ['food', 'good'],
#  ['awesome'],
#  ['want', 'leave'],
#  ['make', 'drive', 'way', 'north', 'scottsdale', 'one', 'bit', 'disappointed'],
#  ['eat'],
#  ['owner',
#   'really',
#   'really',
#   'need',
#   'quit',
#   'soooooo',
#   'cheap',
#   'let',
#   'wrap',
#   'freak',
#   'sandwich',
#   'two',
#   'paper',
#   'one'],
#  ['checked', 'place', 'couple', 'year', 'ago', 'impressed'],
#  ['chicken', 'get', 'definitely', 'reheat', 'ok', 'wedge', 'cold', 'soggy'],
#  ['sorry', 'get', 'food', 'anytime', 'soon'],
#  ['absolute', 'must', 'visit'],
#  ['cow', 'tongue', 'cheek', 'taco', 'amaze'],
#  ['friend', 'like', 'bloody', 'mary'],
#  ['despite',
#   'hard',
#   'rate',
#   'business',
#   'actually',
#   'rare',
#   'give',
#   '1',
#   'star'],
#  ['really', 'want', 'make', 'experience', 'good', 'one'],
#  ['return'],
#  ['chicken', 'pho', 'taste', 'bland'],
#  ['disappoint'],
#  ['grill', 'chicken', 'tender', 'yellow', 'saffron', 'season'],
#  ['drive',
#   'thru',
#   'mean',
#   'want',
#   'wait',
#   'around',
#   'half',
#   'hour',
#   'food',
#   'somehow',
#   'end',
#   'go',
#   'make',
#   'u',
#   'wait',
#   'wait'],
#  ['pretty', 'awesome', 'place'],
#  ['ambience', 'perfect'],
#  ['best',
#   'luck',
#   'rude',
#   'non-customer',
#   'service',
#   'focus',
#   'new',
#   'management'],
#  ['grandmother', 'make', 'roast', 'chicken', 'well', 'one'],
#  ['ask',
#   'multiple',
#   'time',
#   'wine',
#   'list',
#   'time',
#   'ignore',
#   'go',
#   'hostess',
#   'get',
#   'one'],
#  ['staff',
#   'always',
#   'super',
#   'friendly',
#   'helpful',
#   'especially',
#   'cool',
#   'bring',
#   'two',
#   'small',
#   'boy',
#   'baby'],
#  ['four',
#   'star',
#   'food',
#   'guy',
#   'blue',
#   'shirt',
#   'great',
#   'vibe',
#   'still',
#   'let',
#   'u',
#   'eat'],
#  ['roast', 'beef', 'sandwich', 'taste', 'really', 'good'],
#  ['even', 'drastically', 'sick'],
#  ['high-quality', 'chicken', 'chicken', 'caesar', 'salad'],
#  ['order', 'burger', 'rare', 'come', "we'll"],
#  ['promptly', 'greet', 'seat'],
#  ['try', 'go', 'lunch', 'madhouse'],
#  ['proven',
#   'dead',
#   'wrong',
#   'sushi',
#   'bar',
#   'quality',
#   'great',
#   'service',
#   'fast',
#   'food',
#   'impeccable'],
#  ['wait', 'hour', 'seat', 'great', 'mood'],
#  ['good', 'joint'],
#  ['macarons', 'insanely', 'good'],
#  ["i'm", 'eat'],
#  ['waiter', 'attentive', 'friendly', 'informative'],
#  ['maybe', "weren't", 'cold', 'would', 'somewhat', 'edible'],
#  ['place', 'lot', 'promise', 'fails', 'deliver'],
#  ['bad', 'experience'],
#  ['mistake'],
#  ['food', 'average', 'best'],
#  ['great', 'food'],
#  ["won't", 'go', 'back', 'anytime', 'soon'],
#  ['disappointed', 'order', '$35', 'big', 'bay', 'plater'],
#  ['great', 'place', 'relax', 'awesome', 'burger', 'beer'],
#  ['perfect', 'sit-down', 'family', 'meal', 'get', 'together', 'friend'],
#  ['much', 'flavor', 'poorly', 'construct'],
#  ['patio', 'seat', 'comfortable'],
#  ['fry', 'rice', 'dry', 'well'],
#  ['hand', 'favorite', 'italian', 'restaurant'],
#  ['scream', '"legit"', "booksomethat's", 'also', 'pretty', 'rare', 'vega'],
#  ['fun', 'experience'],
#  ['atmosphere',
#   'great',
#   'lovely',
#   'duo',
#   'violinist',
#   'play',
#   'song',
#   'request'],
#  ['personally',
#   'love',
#   'hummus',
#   'pita',
#   'baklava',
#   'falafel',
#   'baba',
#   'ganoush',
#   "it's",
#   'amaze',
#   'eggplant'],
#  ['convenient', 'since', 'stay', 'mgm'],
#  ['owner', 'super', 'friendly', 'staff', 'courteous'],
#  ['great'],
#  ['eclectic', 'selection'],
#  ['sweet', 'potato', 'tot', 'good', 'onion', 'ring', 'perfection', 'close'],
#  ['staff', 'attentive'],
#  ['chef',
#   'generous',
#   'time',
#   'even',
#   'come',
#   'around',
#   'twice',
#   'take',
#   'picture'],
#  ['owner',
#   'use',
#   'work',
#   'nobu',
#   'place',
#   'really',
#   'similar',
#   'half',
#   'price'],
#  ['google', 'mediocre', 'imagine', 'smashburger', 'pop'],
#  ['dont', 'go'],
#  ['promise', "won't", 'disappoint'],
#  ['sushi', 'lover', 'avoid', 'place', 'mean'],
#  ['great', 'double', 'cheeseburger'],
#  ['awesome', 'service', 'food'],
#  ['fantastic', 'neighborhood', 'gem'],
#  ["can't", 'wait', 'go', 'back'],
#  ['plantain', 'bad', "i've", 'ever', 'taste'],
#  ["it's", 'great', 'place', 'highly', 'recommend'],
#  ['service', 'slow', 'attentive'],
#  ['give', '5', 'star', "i'm", 'give', '5', 'star'],
#  ['staff', 'spends', 'time', 'talk'],
#  ['dessert', 'panna', 'cotta', 'amaze'],
#  ['good', 'food', 'great', 'atmosphere1'],
#  ['damn', 'good', 'steak'],
#  ['total', 'brunch', 'fail'],
#  ['price',
#   'reasonable',
#   'flavor',
#   'spot',
#   'sauce',
#   'home',
#   'make',
#   'slaw',
#   'drench',
#   'mayo'],
#  ['decor', 'nice', 'piano', 'music', 'soundtrack', 'pleasant'],
#  ['steak',
#   'amazingrge',
#   'fillet',
#   'relleno',
#   'best',
#   'seafood',
#   'plate',
#   'ever'],
#  ['good', 'food', 'good', 'service'],
#  ['absolutely', 'amaze'],
#  ['probably', "won't", 'back', 'honest'],
#  ['definitely', 'back'],
#  ['sergeant',
#   'pepper',
#   'beef',
#   'sandwich',
#   'auju',
#   'sauce',
#   'excellent',
#   'sandwich',
#   'well'],
#  ['hawaiian',
#   'breeze',
#   'mango',
#   'magic',
#   'pineapple',
#   'delight',
#   'smoothy',
#   "i've",
#   'try',
#   'far',
#   "they're",
#   'good'],
#  ['go', 'lunch', '-', 'service', 'slow'],
#  ['much',
#   'say',
#   'place',
#   'walk',
#   'expect',
#   'amaze',
#   'quickly',
#   'disappointed'],
#  ['mortify'],
#  ['needle', 'say', 'never', 'back'],
#  ['anyways', 'food', 'definitely', 'fill', 'price', 'pay', 'expect'],
#  ['chip', 'come', 'drip', 'grease', 'mostly', 'edible'],
#  ["wasn't", 'really', 'impressed', 'strip', 'steak'],
#  ['go', 'since', '2007', 'every', 'meal', 'awesome'],
#  ['server', 'nice', 'attentive', 'serve', 'staff'],
#  ['cashier', 'friendly', 'even', 'brought', 'food'],
#  ['work',
#   'hospitality',
#   'industry',
#   'paradise',
#   'valley',
#   'refrain',
#   'recommend',
#   'cibo',
#   'longer'],
#  ['atmosphere', 'fun'],
#  ['would', 'recommend', 'others'],
#  ['service', 'quick', 'even', '"to', 'go"', 'order', 'like', 'like'],
#  ['mean', 'really', 'get', 'famous', 'fish', 'chip', "it's", 'terrible'],
#  ['say', 'mouth', 'belly', 'still', 'quite', 'pleased'],
#  ['thing'],
#  ['2', 'thumb'],
#  ['reading', 'please', "don't", 'go'],
#  ['love', 'grill', 'pizza', 'remind', 'legit', 'italian', 'pizza'],
#  ['tonight', 'elk', 'filet', 'specialand', 'suck'],
#  ['order',
#   'old',
#   'classic',
#   'new',
#   'dish',
#   'go',
#   'time',
#   'sorely',
#   'disappointed',
#   'everything'],
#  ['fly', 'apple', 'juice', 'fly'],
#  ['food', 'barely', 'lukewarm', 'must', 'sit', 'wait', 'server', 'bring', 'u'],
#  ["ryan's",
#   'bar',
#   'definitely',
#   'one',
#   'edinburgh',
#   'establishment',
#   "won't",
#   'revisit'],
#  ['probably', 'never', 'come', 'back', "wouldn't", 'recommend'],
#  ["friend's", 'pasta', '--', 'also', 'bad', 'barely', 'touch'],
#  ['way', 'fry'],
#  ["i'm",
#   'sure',
#   'long',
#   'stood',
#   'long',
#   'enough',
#   'begin',
#   'feel',
#   'awkwardly',
#   'place'],
#  ['open', 'sandwich', 'impressed', 'good', 'way'],
#  ['back'],
#  ['watch',
#   'price',
#   'inflate',
#   'portion',
#   'get',
#   'small',
#   'management',
#   'attitude',
#   'grow',
#   'rapidly'],
#  ['main',
#   'thing',
#   "didn't",
#   'enjoy',
#   'crowd',
#   'old',
#   'crowd',
#   'around',
#   'mid',
#   '30'],
#  ['wait', '30', 'minute', 'get', 'drink', 'longer', 'get', '2', 'arepas'],
#  ['service', 'poor', 'thats', 'nice'],
#  ['place', 'clean', 'food', 'oh', 'stale'],
#  ['chicken', 'dish', 'ok', 'beef', 'like', 'shoe', 'leather'],
#  ['service', 'beyond', 'bad'],
#  ['taste', 'like', 'dirt'],
#  ['sashimi', 'poor', 'quality', 'soggy', 'tasteless'],
#  ['food', 'tasty', 'say', '"real', 'traditional', 'hunan', 'style"'],
#  ['bother', 'slow', 'service'],
#  ['frozen', 'margarita', 'way', 'sugary', 'taste'],
#  ['nutshell',
#   '1',
#   'restaraunt',
#   'smell',
#   'like',
#   'combination',
#   'dirty',
#   'fish',
#   'market',
#   'sewer'],
#  ["girlfriend's", 'veal', 'bad'],
#  ['unfortunately', 'good'],
#  ['bland', 'flavorless', 'good', 'way', 'describe', 'barely', 'tepid', 'meat'],
#  ['chain', "i'm", 'fan', 'beat', 'place', 'easily'],
#  ['come', 'back'],
#  ['food', 'arrives', "it's", 'meh'],
#  ['pay',
#   '$785',
#   'hot',
#   'dog',
#   'fry',
#   'look',
#   'like',
#   'come',
#   "kid's",
#   'meal',
#   'wienerschnitzel',
#   'idea',
#   'good',
#   'meal'],
#  ['brother', 'law', 'work', 'mall', 'ate', 'day', 'guess', 'sick', 'night'],
#  ['mediocre', 'food'],
#  ["i'm", 'super', 'pissd'],
#  ['sad', 'little', 'vegetable', 'overcook'],
#  ['high',
#   'hope',
#   'place',
#   'since',
#   'burger',
#   'cooked',
#   'charcoal',
#   'grill',
#   'unfortunately',
#   'taste',
#   'fell',
#   'flat',
#   'way',
#   'flat'],
#  ['single',
#   'employee',
#   'come',
#   'see',
#   'ok',
#   'even',
#   'need',
#   'water',
#   'refill',
#   'finally',
#   'serve',
#   'u',
#   'food'],
#  ['server',
#   'negligent',
#   'need',
#   'make',
#   'u',
#   'feel',
#   'unwelcome',
#   'would',
#   'suggest',
#   'place'],
#  ['service', 'terrible', 'though'],
#  ['place', 'overprice', 'consistent', 'boba', 'really', 'overprice'],
#  ['packed'],
#  ['food', 'terrible'],
#  ['kept', 'get', 'bad', 'bad', "i'm", 'officially'],
#  ['place', 'honestly', 'blown'],
#  ['definitely', 'would', 'eat'],
#  ['waste', 'money'],
#  ['awful', 'service'],
#  ["won't", 'ever', 'go'],
#  ['food', 'quality', 'horrible'],
#  ['price', 'think', 'place', 'would', 'much', 'rather', 'go'],
#  ['service', 'fair', 'best'],
#  ['love',
#   'sushi',
#   'found',
#   'kabuki',
#   'over-priced',
#   'over-hip',
#   'under-services'],
#  ['favor', 'stay', 'away', 'dish'],
#  ['poor', 'service'],
#  ['one', 'table', 'thought', 'food', 'average', 'worth', 'wait'],
#  ['paid', 'bill', 'tip', 'felt', 'server', 'terrible', 'job'],
#  ['never',
#   'bland',
#   'food',
#   'surprised',
#   'consider',
#   'article',
#   'read',
#   'focus',
#   'much',
#   'spice',
#   'flavor'],
#  ['food', 'way', 'overprice', 'portion', 'fuck', 'small'],
#  ['40', 'buck', 'head', 'really', 'expect', 'well', 'food'],
#  ["won't", 'back'],
#  ['could', 'believe', 'dirty', 'oyster'],
#  ['place', 'deserves', 'star'],
#  ['would', 'recommend', 'place'],
#  ['disbelief', 'dish', 'qualify', 'bad', 'version', 'food', 'ever', 'taste'],
#  ['bad',
#   'day',
#   'low',
#   'tolerance',
#   'rude',
#   'customer',
#   'service',
#   'people',
#   'job',
#   'nice',
#   'polite',
#   'wash',
#   'dish',
#   'otherwise'],
#  ['probably', 'would', 'go'],
#  ['wife',
#   'hat',
#   'meal',
#   'coconut',
#   'shrimp',
#   'friend',
#   'really',
#   'enjoy',
#   'meal',
#   'either'],
#  ['fella', 'get', 'huevos', 'rancheros', "didn't", 'look', 'appeal'],
#  ['probably', "won't", 'come', 'back'],
#  ['bad', 'food/service', "i've"],
#  ['hot',
#   'dish',
#   'hot',
#   'cold',
#   'dish',
#   'close',
#   'room',
#   'tempo',
#   'watch',
#   'staff',
#   'prepare',
#   'food',
#   'bare',
#   'hand',
#   'gloveseverything',
#   'deep',
#   'fry',
#   'oil'],
#  ['feel',
#   'din',
#   'room',
#   'college',
#   'cooking',
#   'course',
#   'high',
#   'class',
#   'din',
#   'service',
#   'slow',
#   'best'],
#  ['start', 'review', 'two', 'star', "i'm", 'edit', 'give', 'one'],
#  ['bad', 'sushi', 'ever', 'eat', 'besides', "costco's"],
#  ['weird', 'vibe', 'owner'],
#  ['hardly', 'meat'],
#  ["i've", 'well', 'bagel', 'grocery', 'store'],
#  ['burger', "aren't", 'good', 'pizza', 'use', 'amaze', 'doughy', 'flavorless'],
#  ['found', 'six', 'inch', 'long', 'piece', 'wire', 'salsa'],
#  ['service', 'terrible', 'food', 'mediocre'],
#  ['order',
#   'albondigas',
#   'soup',
#   '-',
#   'warm',
#   '-',
#   'taste',
#   'like',
#   'tomato',
#   'soup',
#   'frozen',
#   'meatball'],
#  ['three',
#   'different',
#   'occasion',
#   'ask',
#   'well',
#   'medium',
#   'well',
#   'three',
#   'time',
#   'get',
#   'bloodiest',
#   'piece',
#   'meat',
#   'plate'],
#  ['two', 'bite', 'refuse', 'eat', 'anymore'],
#  ['service', 'extremely', 'slow'],
#  ['20', 'minute', 'wait', 'get', 'table'],
#  ['way', 'plug', 'u', 'unless', 'go', 'converter'],
#  ['good', 'case', 'excellent', 'value'],
#  ['great', 'jawbone'],
#  ['tie', 'charger', 'conversation', 'last', '45', 'minutesmajor', 'problem'],
#  ['mic', 'great'],
#  ['jiggle', 'plug', 'get', 'line', 'right', 'get', 'decent', 'volume'],
#  ['several',
#   'dozen',
#   'several',
#   'hundred',
#   'contact',
#   'imagine',
#   'fun',
#   'send',
#   'one',
#   'one'],
#  ['razr', 'owneryou', 'must'],
#  ['needle', 'say', 'waste', 'money'],
#  ['waste', 'money', 'time'],
#  ['sound', 'quality', 'great'],
#  ['impressed', 'go', 'original', 'battery', 'extend', 'battery'],
#  ['two',
#   'seperated',
#   'mere',
#   '5',
#   'ft',
#   'start',
#   'notice',
#   'excessive',
#   'static',
#   'garble',
#   'sound',
#   'headset'],
#  ['good', 'quality', 'though'],
#  ['design', 'odd', 'ear', '"clip"', 'comfortable'],
#  ['highly', 'recommend', 'one', 'blue', 'tooth', 'phone'],
#  ['advise', 'everyone', 'fool'],
#  ['far', 'good'],
#  ['work', 'great'],
#  ['click',
#   'place',
#   'way',
#   'make',
#   'wonder',
#   'long',
#   'mechanism',
#   'would',
#   'last'],
#  ['go',
#   "motorola's",
#   'website',
#   'follow',
#   'direction',
#   'could',
#   'get',
#   'pair'],
#  ['bought', 'use', 'kindle', 'fire', 'absolutely', 'love'],
#  ['commercial', 'mislead'],
#  ['yet',
#   'run',
#   'new',
#   'battery',
#   'two',
#   'bar',
#   "that's",
#   'three',
#   'day',
#   'without',
#   'charge'],
#  ['bought', 'mother', 'problem', 'battery'],
#  ['great', 'pocket', 'pc', '/', 'phone', 'combination'],
#  ["i've",
#   'phone',
#   '7',
#   'month',
#   'say',
#   "it's",
#   'best',
#   'mobile',
#   'phone',
#   "i've"],
#  ["didn't", 'think', 'instruction', 'provide', 'helpful'],
#  ['people', 'couldnt', 'hear', 'talk', 'pull', 'earphone', 'talk', 'phone'],
#  ["doesn't", 'hold', 'charge'],
#  ['simple', 'little', 'phone', 'use', 'breakage', 'unacceptible'],
#  ['product', 'ideal', 'people', 'like', 'whose', 'ear', 'sensitive'],
#  ['unusable', 'move', 'car', 'freeway', 'speed'],
#  ['two', 'year', 'left', 'contract', 'hate', 'phone'],
#  ['car',
#   'charger',
#   'well',
#   'ac',
#   'charger',
#   'include',
#   'make',
#   'sure',
#   'never',
#   'run',
#   'juicehighy',
#   'recommend'],
#  ['need',
#   'least',
#   '3',
#   'min',
#   'get',
#   'phone',
#   'book',
#   'time',
#   'first',
#   'turn',
#   'phonebattery',
#   'life',
#   'short'],
#  ['kept', 'well'],
#  ['poor', 'talk', 'time', 'performance'],
#  ['case', 'great', 'work', 'fine', '680'],
#  ['worthless', 'product'],
#  ['great',
#   'camera',
#   'thats',
#   '2mp',
#   'pic',
#   'nice',
#   'clear',
#   'great',
#   'picture',
#   'quality'],
#  ['impressed', 'product'],
#  ['nice', 'headset', 'price', 'right'],
#  ['hear', 'garbage', 'audio'],
#  ['excellent', 'bluetooth', 'headset'],
#  ['feature', 'want'],
#  ['right', 'mind', 'gonna', 'buy', 'battery'],
#  ['argue',
#   'verizon',
#   'regard',
#   'drop',
#   'call',
#   'return',
#   'phone',
#   'two',
#   'day'],
#  ['case', 'seem', 'well', 'make'],
#  ['disappointed', 'battery'],
#  ['loud', 'enough', "doesn't", 'turn', 'like'],
#  ['good', 'protection', 'make', 'phone', 'bulky'],
#  ['usable',
#   'keyboard',
#   'actually',
#   'turn',
#   'pda',
#   'real-world',
#   'useful',
#   'machine',
#   'instead',
#   'neat',
#   'gadget'],
#  ['phone', 'pretty', 'sturdy', "i've", 'never', 'large', 'problem'],
#  ['love', 'thing'],
#  ['everything', 'fine', 'reasonable', 'price', 'ie'],
#  ['disappointed'],
#  ['even',
#   'drop',
#   'phone',
#   'stream',
#   'submerge',
#   '15',
#   'second',
#   'still',
#   'work',
#   'great'],
#  ['happy', '510', 'complaint', 'one', 'regard', 'sound', 'quality', 'end'],
#  ['button', 'bad'],
#  ['essentially', 'forget', "microsoft's", 'tech', 'support'],
#  ['really',
#   'recommend',
#   'faceplate',
#   'since',
#   'look',
#   'nice',
#   'elegant',
#   'cool'],
#  ['headphone',
#   'great',
#   'find',
#   '-',
#   'think',
#   'perhaps',
#   'best',
#   'purchase',
#   "i've",
#   'make',
#   'last',
#   'several',
#   'year',
#   '-',
#   'seriously'],
#  ['buy', 'different', 'phone', '-'],
#  ['hold', 'phone', 'particular', 'angle', 'party', 'hear', 'clearly'],
#  ['one',
#   'big',
#   'drawback',
#   'mp3',
#   'player',
#   'button',
#   "phone's",
#   'front',
#   'cover',
#   'let',
#   'pause',
#   'skip',
#   'song',
#   'lock',
#   'second'],
#  ['week', 'later', 'activate', 'suddenly', 'die'],
#  ['feel',
#   'comfortable',
#   'headset',
#   'wear',
#   'glass',
#   'get',
#   'way',
#   'sometimes'],
#  ['great', 'ipod'],
#  ['device', 'great', 'several', 'situations1'],
#  ['mic', "doesn't", 'work'],
#  ['even',
#   'bmw',
#   '3',
#   'series',
#   'fairly',
#   'quiet',
#   'trouble',
#   'hearing',
#   'person',
#   'say'],
#  ['great', 'choice'],
#  ['nice', 'dock', 'station', 'home', 'work'],
#  ['beautiful', 'phone'],
#  ['love', 'product'],
#  ['buy', 'd807wrongly', 'advertised', 'd807'],
#  ['great', 'little', 'item'],
#  ['love', 'phone', 'handy', 'lot', 'feature'],
#  ['purchase', 'within', '2', 'day', 'longer', 'work'],
#  ['wear', 'everyday', 'hold', 'well'],
#  ['good', 'bargain'],
#  ['well', 'package', 'arrive', 'time', 'work', 'intend'],
#  ['battery', 'run', 'quickly'],
#  ['item', 'work', 'great', 'broke', '6', 'month', 'use'],
#  ['headset', 'easy', 'use', 'everyone', 'love'],
#  ['phone', 'work', 'great'],
#  ['construction', 'headset', 'poor'],
#  ['product', 'excellent', 'work', 'well', 'verizon', 'one', 'boy', 'cheaper'],
#  ['phone', 'load', 'super'],
#  ['product',
#   'cost',
#   'much',
#   'one',
#   'expect',
#   'work',
#   'far',
#   'well',
#   'great',
#   'ease',
#   'thing'],
#  ['make', 'sturdy'],
#  ['work', 'great'],
#  ['ear', 'bud', 'play', 'music', 'one', 'ear'],
#  ['dont', 'waste', 'money'],
#  ['order'],
#  ['plan', 'use', 'car', 'forget'],
#  ['found', 'product', 'waaay', 'big'],
#  ['best',
#   "i've",
#   'found',
#   'far',
#   "i've",
#   'try',
#   '2',
#   'bluetooths',
#   'one',
#   'best',
#   'quality',
#   'listener',
#   'well',
#   'ease',
#   'use'],
#  ["i'm", 'disappointed', 'decision'],
#  ['integrate', 'seamlessly', 'motorola', 'razr', 'phone'],
#  ['buyer', 'beware', 'could', 'flush', 'money', 'right', 'toilet'],
#  ['definitely', 'bargain'],
#  ['price', 'good', 'free', 'shipping', 'good', 'purchase'],
#  ['receive',
#   'supposedly',
#   'new',
#   'motorola',
#   '375',
#   'apparently',
#   'match',
#   'phone',
#   'charger'],
#  ['pros-good',
#   'camera',
#   '-',
#   'nice',
#   'picture',
#   'also',
#   'cool',
#   'style',
#   'like',
#   'black',
#   'white'],
#  ["that's",
#   'huge',
#   'design',
#   'flaw',
#   'unless',
#   "i'm",
#   'use',
#   'correctly',
#   "don't",
#   'think',
#   'case'],
#  ['love',
#   '350',
#   'headset',
#   'jabra350',
#   'bluetooth',
#   'headset',
#   'great',
#   'reception',
#   'good',
#   'ear',
#   'piece',
#   'comfortable',
#   'fit'],
#  ['camera',
#   'although',
#   'rat',
#   'impressive',
#   '13',
#   'megapixels',
#   'render',
#   'image',
#   'fall',
#   'well',
#   'expectation',
#   'relatively',
#   'high',
#   'resolution'],
#  ['purcashed', 'car', 'charger', 'work'],
#  ['sound',
#   'quality',
#   'end',
#   'excellent',
#   'use',
#   'headset',
#   'call',
#   'wife',
#   'ask',
#   'wife',
#   'use',
#   'headset',
#   'call',
#   '2'],
#  ['phone', 'slim', 'light', 'display', 'beautiful'],
#  ['little',
#   'geeky',
#   'think',
#   'thats',
#   'sex',
#   'toast',
#   'rock',
#   'ooze',
#   'sex',
#   'right',
#   'battery',
#   'embed',
#   'sleek',
#   'stylish',
#   'leather',
#   'case'],
#  ['great', 'product', 'fast', 'shipping'],
#  ['absolutely', 'great'],
#  ['keyboard',
#   'nice',
#   'compromise',
#   'full',
#   'qwerty',
#   'basic',
#   'cell',
#   'phone',
#   'number',
#   'keypad'],
#  ['get', 'phone', 'around', 'end', 'may', "i'm", 'completely', 'unhappy'],
#  ['comfortable', 'ear'],
#  ['winner', 'u'],
#  ['setup', "couldn't", 'simpler'],
#  ["i've",
#   'try',
#   'several',
#   'different',
#   'earpiece',
#   'cell',
#   'phone',
#   'jabra',
#   'one',
#   'first',
#   'one',
#   "i've",
#   'found',
#   'fit',
#   'ear',
#   'comfortably'],
#  ['could', 'get', 'strong', 'enough', 'signal'],
#  ['iam', 'pleased', 'purchase'],
#  ['bad', 'quality'],
#  ['get', 'job'],
#  ['great', 'audio'],
#  ['basically', 'service', 'bad'],
#  ['work', 'cell', 'phone', 'plug', 'set', 'charger'],
#  ["i've", 'bluetooth', 'week', 'really', 'like'],
#  ['bt', 'headset', 'disapoinment'],
#  ['small', "don't", 'even', 'realize', 'get', 'use'],
#  ['accompany', 'software', 'almost', 'brilliant'],
#  ['headset', 'work', 'great', 'package', 'nicely', 'avoid', 'damage'],
#  ['definitly', 'recommend'],
#  ['buyer--be', 'careful'],
#  ['majority', 'logitech', 'earbud', 'headset', 'fail'],
#  ['good', 'stuff', 'price'],
#  ['headset', 'work', 'peachy-keen'],
#  ['house', 'get', 'drop', 'coverage', 'upstairs', 'coverage', 'basement'],
#  ['voice', 'recognition', 'tremendous'],
#  ['waste'],
#  ['several',
#   'different',
#   '2',
#   'minute',
#   'call',
#   'experienced',
#   '5',
#   'drop',
#   'area',
#   '5',
#   'bar'],
#  ['happy', 'item'],
#  ['disappointed'],
#  ['phone', 'take', 'forever', 'charge', 'like', '2', '5', 'hour', 'literally'],
#  ['get', 'phone', 'reccomendation', 'relative', "i'm", 'glad'],
#  ['waste', 'time'],
#  ['reception', 'poor'],
#  ['item', 'state', 'include', 'description', 'include'],
#  ['3', 'month', 'screen', 'go', 'black', 'sudden'],
#  ['hop'],
#  ['audio', 'quality', 'poor', 'poor'],
#  ['absolutely', 'problem', 'headset', 'link', '8530', 'blackberry', 'curve'],
#  ['know',
#   'sound',
#   'funny',
#   'seem',
#   'like',
#   'sketchy',
#   'technology',
#   "wouldn't",
#   'work',
#   'wellwell',
#   'one',
#   'work',
#   'great'],
#  ["i've", 'bought', '$5', 'wire', 'headphone', 'sound', 'well'],
#  ['phone',
#   'fast',
#   'send',
#   'kind',
#   'message',
#   'web',
#   'browsing',
#   'significantly',
#   'faster',
#   'previous',
#   'phone',
#   'use'],
#  ['nice', 'quality', 'build', 'unlike', 'cheap'],
#  ['item', 'fantastic', 'work', 'perfectly'],
#  ['love', 'color'],
#  ['w810i', 'superb'],
#  ['whine', 'internet', 'goesthe', 'use', 'thing', 'less', 'like'],
#  ['great', 'charger'],
#  ['essentially', 'communication', 'tool', 'communicate'],
#  ['work', 'like', 'charm', 'work', 'one', 'get', 'phone'],
#  ['still',
#   'maintain',
#   'monkey',
#   "shouldn't",
#   'make',
#   'headphone',
#   'obviously',
#   "don't",
#   'share',
#   'enough',
#   'dna',
#   'copy',
#   'design',
#   'human'],
#  ['great', 'value'],
#  ["doesn't", 'work', 'bougth', 'l7c', 'work'],
#  ['look', 'sharp', 'screen', 'nice', 'clear', 'great', 'graphic'],
#  ["doesn't", 'last', 'long'],
#  ['one', 'thing', 'hate', 'mode', 'set', 'button', 'side'],
#  ['excellent', 'service'],
#  ['thank', 'waste', 'money'],
#  ['bethe', 'audio', 'quality', 'poor'],
#  ['igo', 'charger', 'tip', 'really', 'great'],
#  ['file', 'browser', 'offer', 'option', 'one', 'needshandsfree', 'great'],
#  ['superb', 'phone', 'great', 'network'],
#  ['connect',
#   "wife's",
#   'bluetoothmotorola',
#   'hs850',
#   'phone',
#   'work',
#   'like',
#   'charm',
#   'whether',
#   'phone',
#   'pocket',
#   'case'],
#  ['put', 'late', 'v115g', 'like', 'slow', 'crawl', 'lock', 'every'],
#  ['recognizes', 'phone', 'storage', 'device'],
#  ['like', 'loud', 'buzzing', 'override', 'conversation', 'phone'],
#  ["don't", 'buy', 'product'],
#  ["i've",
#   'bluetoooth',
#   'headset',
#   'time',
#   'still',
#   'comfortable',
#   'way',
#   'fit',
#   'ear'],
#  ['sound', 'quality', 'good', 'functionality', 'awesome'],
#  ['phone', 'thorn', 'side', 'really', 'abhor'],
#  ['recently',
#   'problem',
#   'could',
#   'stay',
#   'connect',
#   '10',
#   'minute',
#   'disconnect'],
#  ['incredible'],
#  ['design', 'flaw'],
#  ['great', 'phone'],
#  ['waste', '13', 'buck'],
#  ['check',
#   'voice',
#   'mail',
#   'night',
#   'keypad',
#   'backlight',
#   'turn',
#   'second',
#   'first',
#   'message',
#   "i'm",
#   'lose'],
#  ['replacement', 'die', 'week'],
#  ['ring', 'toneoverall', 'good', 'phone', 'buy'],
#  ['lately', 'extremely', 'nice', 'helpful', 'phone'],
#  ['problem', 'wit', 'hit', 'drop', 'signal'],
#  ['impressed'],
#  ['light', 'weight', 'hardly', 'notice'],
#  ["you'll", 'love', 'thin'],
#  ['bad', 'choice'],
#  ['pleather', 'case', "doesn't", 'fit'],
#  ['useless', 'phone', 'simply', 'deaf'],
#  ...]

# %% [markdown]
# ## Bag of Words

# %%
"""
dic is a dictionary where key is the word shows in train_data and the items
of is a list with two elements, first one is the frequency of the key and 
second element is the index of the key in feature vector, which we will use
after.
"""
def bagOfWord(data):
    dic = {}
    t = 0
    n = 0
    for dataset in data:
        for line in dataset:
            for word in line:
                if word in dic:
                    dic[word][0] += 1
                elif t == 0:
                    dic[word] = [1,n]
                    n+=1
        t = 1
    return dic

# %%
Dic = bagOfWord([train_data, test_data])
len(Dic)
# Out:
# 4058

# %%
"""Build feature vector."""
def buildB(data, dic):
    data_b = []
    size_dic = len(dic)
    for line in data:
        temp = [0]*size_dic
        for word in line:
            if word in dic:
                temp[dic[word][1]]+=1.0
        data_b.append(np.array(temp))
    return data_b

# %%
# %time [train_data_b, test_data_b] = [buildB(train_data,Dic), buildB(test_data,Dic)]
# Out:
# CPU times: user 1.41 s, sys: 49.8 ms, total: 1.46 s
# Wall time: 1.48 s

# %%
for i in test_data_b:
    if not np.linalg.norm(i):
        print('yes')
        break
# Out:
# yes

# %% [markdown]
# ### postprocess feature vectors

# %%
"""
l^2 normalization
"""
def l2normalize(data):
    for vector in data:
        L = np.linalg.norm(vector)
        if L:
            vector /= L
                
def standardize(data_b, size_dic):
    s = np.array([0.0]*size_dic)
    for bite in data_b:
        s += bite
    s_ = s/len(data_b)
    vec = []
    for bit in data_b:
            vec.append(bit - s_)
    return np.array(vec)

# %%
"""
train_vec and test_vec will be the feature vector to be used for future.
"""
l2normalize(train_data_b), l2normalize(test_data_b)
[train_vec, test_vec] = [standardize(train_data_b,len(Dic)), standardize(test_data_b,len(Dic))]

# %% [markdown]
# # K-means

# %%
"""
randomly pick two points in sample set to be initial points
label is a list indicate which cluster the vector is signed to.
p is the list including two mean point that the model converget to.
During the function, it first prints which two points function pick as
initial points and then how many time it iterates.
"""
def KMeans_2(data,size_dic):
    ##p = kmeans.cluster_centers_
    ##label = kmeans.labels_
    a = random.randint(0,len(data)-1)
    b = random.randint(0,len(data)-1)
    while a==b:
        b = random.randint(0,len(data)-1)
    p = np.array([data[a], data[b]])
    print("point_init1 is ",a)
    print("point_init2 is ",b)
    label = [0]*len(data)
    conver = False
    count = 0
    while not conver:
        count += 1
        conver = True
        for i in range(len(data)):
            d = [0]*2
            d[0] = np.linalg.norm(p[0]-data[i])
            d[1] = np.linalg.norm(p[1]-data[i])
            if d[label[i]] > d[1-label[i]]:
                conver = False
                label[i] = 1-label[i]
        if not conver:
            ##print("a")
            for j in [0,1]:
                n_p = 0
                s_p = np.array([0.0]*size_dic)
                for point in range(len(label)):
                    if label[point] == j:
                        s_p += data[point]
                        n_p += 1
                p[j] = s_p/n_p
    print("iterate time is ",count)
    return(label, p)

# %%
def n_kmeans(vec, k_train_label,kmeans_lib,size):
    [k_label, k_p]=KMeans_2(vec, size)
    n_bruce = 0
    n_python = 0
    for i in range(len(k_label)):
        if k_train_label[i] == kmeans_lib.labels_[i]:
            n_python+=1
        if k_train_label[i] == k_label[i]:
            n_bruce+=1
    print("self-designed accuracy is",n_bruce/len(k_label))
    print("          lib accuracy is", n_python/len(k_label))
    print("centers are:")
    print(k_p)
    print("higher than lib?: ",n_python/len(k_label)<n_bruce/len(k_label) )
    print("************************")

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(train_vec)

# %%
for i in range(1):
    n_kmeans(train_vec, train_label, kmeans,len(Dic))
# Out:
# point_init1 is  85
# point_init2 is  2226
# iterate time is  13
# self-designed accuracy is 0.50875
#           lib accuracy is 0.44125
# centers are:
# [[  1.16586891e-04   1.34438068e-03   5.12423086e-05 ...,   1.38135127e-05
#     1.38135127e-05   1.38135127e-05]
#  [ -8.79173034e-04  -1.01378743e-02  -3.86414420e-04 ...,  -1.04166667e-04
#    -1.04166667e-04  -1.04166667e-04]]
# higher than lib?:  True
# ************************

# %% [markdown]
# ### Logistic Regression

# %%
lgr = LGR()
lgr.fit(train_vec ,train_label)
lgr.score(test_vec,test_label)
# Out:
# 0.80000000000000004

# %% [markdown]
# # N-gram model

# %%
def Ngram(data):
    data_ng = []
    for line in data:
        line_new = []
        for i in range(len(line)-1):
            line_new.append(line[i]+' '+line[i+1])
        data_ng.append(line_new)
    return data_ng

# %%
train_data_ng = Ngram(train_data)
test_data_ng = Ngram(test_data)

# %%
Dic_ng = bagOfWord([train_data_ng, test_data_ng])
len(Dic_ng)
# Out:
# 11372

# %%
# %time [train_data_ng_b, test_data_ng_b] = [buildB(train_data_ng,Dic_ng), buildB(test_data_ng,Dic_ng)]
# Out:
# CPU times: user 3.85 s, sys: 94.8 ms, total: 3.94 s
# Wall time: 3.98 s

# %%
##drop empty element
train_label_ng = train_label[:]
i = 0
while i < len(train_data_ng_b):
    if not np.linalg.norm(train_data_ng_b[i]):
        train_label_ng.pop(i)
        train_data_ng_b.pop(i)
        train_data_ng.pop(i)
    else:
        i+=1
        
test_label_ng = test_label[:]
i = 0
while i < len(test_data_ng_b):
    if not np.linalg.norm(test_data_ng_b[i]):
        test_label_ng.pop(i)
        test_data_ng_b.pop(i)
        test_data_ng.pop(i)
    else:
        i+=1

# %%
l2normalize(train_data_ng_b)
l2normalize(test_data_ng_b)
[train_vec_ng, test_vec_ng] = [standardize(train_data_ng_b, len(Dic_ng)), standardize(test_data_ng_b, len(Dic_ng))]

# %%
kmeans_ng = KMeans(n_clusters=2, random_state=0).fit(train_vec_ng)

# %%
for i in range(1):
    n_kmeans(train_vec_ng, train_label_ng, kmeans_ng, len(Dic_ng))
# Out:
# point_init1 is  1876
# point_init2 is  2298
# iterate time is  2
# self-designed accuracy is 0.49654576856649396
#           lib accuracy is 0.5043177892918825
# centers are:
# [[  3.95997158e-07   1.70272111e-06   5.60024551e-07 ...,   1.44597717e-07
#     1.44597717e-07   1.44597717e-07]
#  [ -3.05313809e-04  -1.31279798e-03  -4.31778929e-04 ...,  -1.11484840e-04
#    -1.11484840e-04  -1.11484840e-04]]
# higher than lib?:  False
# ************************

# %%
lgr = LGR()
lgr.fit(train_vec_ng ,train_label_ng)
lgr.score(test_vec_ng,test_label_ng)
# Out:
# 0.76056338028169013

# %% [markdown]
# ## PCA

# %%
U, s, V = np.linalg.svd(train_vec, full_matrices=True)

# %%
s.shape, V.shape
# Out:
# ((2400,), (4058, 4058))

# %%
train_vec[0].dot(V[:5].T)
# Out:
# array([-0.0495421 ,  0.03947017, -0.07532169,  0.07609576, -0.03962555])

# %%
def reduce(n):
    train_vec_n = train_vec.dot(V[:n].T)
    test_vec_n = test_vec.dot(V[:n].T)
    kmeans_n = KMeans(n_clusters=2, random_state=0).fit(train_vec_n)
    for i in range(1):
        n_kmeans(train_vec_n, train_label, kmeans_n, n)
    lgr = LGR()
    lgr.fit(train_vec_n ,train_label)
    print("Logistic Regression result is",lgr.score(test_vec_n,test_label))

# %%
reduce(10)
# Out:
# point_init1 is  567
# point_init2 is  1289
# iterate time is  4
# self-designed accuracy is 0.5025
#           lib accuracy is 0.44208333333333333
# centers are:
# [[ 0.01862558 -0.09529385  0.04098942  0.11560459  0.14163764  0.0322151
#    0.08448645  0.02488959 -0.03347525 -0.23618515]
#  [-0.00098029  0.00501547 -0.00215734 -0.00608445 -0.00745461 -0.00169553
#   -0.00444666 -0.00130998  0.00176186  0.0124308 ]]
# higher than lib?:  True
# ************************
# Logistic Regression result is 0.633333333333

# %%
reduce(50)
# Out:
# point_init1 is  708
# point_init2 is  580
# iterate time is  5
# self-designed accuracy is 0.49916666666666665
#           lib accuracy is 0.44166666666666665
# centers are:
# [[ -3.85958262e-02   2.98788553e-02   1.09260325e-03  -3.50402718e-02
#    -6.03908006e-02   2.71285544e-02   9.24205680e-02  -2.42083049e-02
#    -1.16878912e-02  -4.17813085e-02  -1.08842813e-03   9.82827612e-02
#    -1.06257074e-01   7.95867231e-02   2.71005850e-01  -1.91636199e-02
#     1.19027426e-01   6.27011539e-02   2.37796589e-02  -4.12539733e-02
#     5.71128940e-02   4.97341417e-03   4.46629939e-02  -2.72566169e-02
#    -2.55405800e-02  -6.76200807e-03   1.13661894e-02  -8.78335209e-03
#    -4.75150784e-03   7.61861380e-03  -4.62395727e-03   4.67152023e-03
#     2.84586015e-03   2.14300684e-03   1.18431878e-03  -6.56355824e-03
#     1.43377025e-03   1.90586999e-03   5.79876858e-03  -1.32462988e-03
#     4.29970564e-03  -7.10216944e-04  -9.32155332e-04   2.95507672e-04
#    -5.11507905e-03  -2.94108678e-03  -8.33417749e-04   5.63885268e-03
#    -6.25949371e-04  -1.01722408e-03]
#  [  1.64308904e-03  -1.27199297e-03  -4.65139525e-05   1.49172313e-03
#     2.57093764e-03  -1.15490805e-03  -3.93449855e-03   1.03058813e-03
#     4.97573128e-04   1.77870036e-03   4.63362104e-05  -4.18406194e-03
#     4.52354180e-03  -3.38814026e-03  -1.15371735e-02   8.15827434e-04
#    -5.06719709e-03  -2.66929326e-03  -1.01233995e-03   1.75625082e-03
#    -2.43139166e-03  -2.11726580e-04  -1.90137854e-03   1.16035989e-03
#     1.08730532e-03   2.87870022e-04  -4.83877741e-04   3.73922026e-04
#     2.02279656e-04  -3.24337164e-04   1.96849614e-04  -1.98874449e-04
#    -1.21153039e-04  -9.12313945e-05  -5.04184365e-05   2.79421680e-04
#    -6.10380037e-05  -8.11360812e-05  -2.46863302e-04   5.63917150e-05
#    -1.83045679e-04   3.02351262e-05   3.96834155e-05  -1.25802571e-05
#     2.17757492e-04   1.25206996e-04   3.54799910e-05  -2.40055414e-04
#     2.66477143e-05   4.33049348e-05]]
# higher than lib?:  True
# ************************
# Logistic Regression result is 0.668333333333

# %%
reduce(100)
# Out:
# point_init1 is  1674
# point_init2 is  739
# iterate time is  5
# self-designed accuracy is 0.5125
#           lib accuracy is 0.44166666666666665
# centers are:
# [[ -2.58300899e-02   1.87944688e-02  -3.13997139e-02   5.03425740e-02
#     1.25379216e-02  -5.98003149e-03  -9.05578367e-02   5.50654209e-02
#     1.15977233e-01  -1.96191894e-01   1.35022180e-01   5.23498559e-02
#    -1.72298261e-01   1.59890578e-03  -7.26419893e-02   2.85466726e-02
#     2.68612741e-02  -4.02900039e-03   4.73988738e-03   3.10942854e-02
#     4.57722255e-03  -4.20099517e-03  -1.87796410e-02   1.58850513e-03
#    -3.95072934e-02   5.20537500e-02   2.05245987e-02  -1.09424503e-04
#     7.63602357e-04   9.57360179e-03  -7.90333903e-03   7.59567835e-03
#     8.61797566e-03   4.44212040e-05  -3.78065237e-03  -5.93526239e-03
#    -1.24102836e-05  -2.39677943e-03  -3.81382343e-03   1.58868143e-03
#    -2.21226722e-03  -2.20930982e-03  -1.32397568e-03  -2.76130301e-03
#     2.10583604e-03   6.62133470e-04  -3.32544027e-03   1.16283299e-03
#    -1.36648913e-04   1.26253886e-03   1.26420160e-03   3.06023800e-03
#    -2.83642159e-03   5.95940633e-03  -2.66534848e-03   2.47196108e-03
#    -2.41367746e-04  -1.59449264e-03   8.74827793e-04  -2.63961703e-03
#     1.23478977e-03  -3.21497245e-04   2.66837224e-03  -1.57690752e-03
#    -7.24297982e-04   2.10556563e-03   6.53278080e-04   3.66389556e-04
#     2.30952366e-05   8.45551883e-04   9.73174091e-04   7.63722400e-04
#    -1.97916170e-03  -2.02590841e-03   2.48943272e-03  -2.66205216e-03
#    -1.94032733e-03   1.30416979e-03   3.47796044e-04   1.38701110e-03
#    -3.43476862e-04  -8.62623994e-05   3.27158342e-04  -1.42614911e-03
#    -2.64258275e-04   9.43481052e-04  -3.15416390e-03   1.06864619e-03
#    -4.53549522e-04  -1.48522095e-03   6.15505349e-05   4.77883522e-04
#     9.26286146e-04  -7.44818991e-04   2.40544444e-03  -1.45303115e-03
#    -9.38863400e-04   5.16367293e-04  -7.98469269e-04  -9.68060202e-04]
#  [  1.31186096e-03  -9.54535192e-04   1.59473153e-03  -2.55680323e-03
#    -6.36777106e-04   3.03714384e-04   4.59925966e-03  -2.79666761e-03
#    -5.89026228e-03   9.96421180e-03  -6.85751877e-03  -2.65874925e-03
#     8.75069979e-03  -8.12053721e-05   3.68934797e-03  -1.44983101e-03
#    -1.36423284e-03   2.04625239e-04  -2.40729832e-04  -1.57921940e-03
#    -2.32468396e-04   2.13360525e-04   9.53782119e-04  -8.06771434e-05
#     2.00650001e-03  -2.64371059e-03  -1.04240519e-03   5.55746162e-06
#    -3.87819061e-05  -4.86224960e-04   4.01395503e-04  -3.85770004e-04
#    -4.37690533e-04  -2.25606816e-06   1.92012117e-04   3.01440647e-04
#     6.30294613e-07   1.21727852e-04   1.93696812e-04  -8.06860970e-05
#     1.12356829e-04   1.12206629e-04   6.72421973e-05   1.40241309e-04
#    -1.06951392e-04  -3.36284950e-05   1.68892763e-04  -5.90580679e-05
#     6.94013745e-06  -6.41219386e-05  -6.42063860e-05  -1.55423646e-04
#     1.44056438e-04  -3.02666871e-04   1.35367961e-04  -1.25546185e-04
#     1.22586071e-05   8.09812374e-05  -4.44308336e-05   1.34061110e-04
#    -6.27126153e-05   1.63282314e-05  -1.35521532e-04   8.00881230e-05
#     3.67857119e-05  -1.06937659e-04  -3.31787466e-05  -1.86082261e-05
#    -1.17296298e-06  -4.29439660e-05  -4.94256543e-05  -3.87880028e-05
#     1.00517845e-04   1.02892021e-04  -1.26433536e-04   1.35200547e-04
#     9.85455212e-05  -6.62362942e-05  -1.76638971e-05  -7.04436461e-05
#     1.74445341e-05   4.38110260e-06  -1.66157477e-05   7.24313908e-05
#     1.34211733e-05  -4.79176016e-05   1.60193963e-04  -5.42745003e-05
#     2.30349144e-05   7.54315371e-05  -3.12603417e-06  -2.42707918e-05
#    -4.70443051e-05   3.78279347e-05  -1.22167931e-04   7.37966782e-05
#     4.76830798e-05  -2.62253091e-05   4.05527300e-05   4.91659297e-05]]
# higher than lib?:  True
# ************************
# Logistic Regression result is 0.728333333333

# %%
##compare with PCA Lib
from sklearn.decomposition import PCA
pca = PCA(n_components=100)
pca.fit(train_vec)
abs(abs(V[:100])-abs(pca.components_)) < 0.0000000000001
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]], dtype=bool)
